# %% [markdown]
# ## Adults: Convictions to a criminal measure, by type of measure, Switzerland and cantons [2018-2020]

# %% [markdown]
# Tentative d'analyse des différentes mesures de contraintes en Suisse

# %%
import pandas as pd

# %%
df_sheet_map = pd.read_excel('adult_convictions_ch_2018-2020.xlsx', sheet_name=None, skiprows=1)
df_sheet_map
# Out:
# {'Total':                                                  Year  Total  \
#  0                                                2018  459.0
#  1                                                2019  478.0
#  2                                              2020 6  450.0
#  3   State of the Register of Criminal Conduct: 07....    NaN
#  4   ¹ Prior to 1.1. 2007: Incarceration of abnorma...    NaN
#  5   2 Prior to 1.1. 2007: In-patient measure for a...    NaN
#  6   3 Prior to 1.1. 2007: In-patient treatment of ...    NaN
#  7   4 Prior to 1.1. 2007: Out-patient treatment of...    NaN
#  8   5 Prior to 1.1. 2007: Admission to vocational ...    NaN
#  9   6 The statistics on adult convictions (SUS) is...    NaN
#  10  Source: Federal Statistical Office - Criminal ...    NaN
#  11                                       © FSO – 2021    NaN
#  12                                                NaN    NaN
#  13  Information: Federal Statistical Office (FSO),...    NaN
#
# ...

# %%
df_sheet_map['VS']
# Out:
#                                                  Year  Total  \
# 0                                                2018   16.0
# 1                                                2019   24.0
# 2                                              2020 6   13.0
# 3   State of the Register of Criminal Conduct: 07....    NaN
# 4   ¹ Prior to 1.1. 2007: Incarceration of abnorma...    NaN
# 5   2 Prior to 1.1. 2007: In-patient measure for a...    NaN
# 6   3 Prior to 1.1. 2007: In-patient treatment of ...    NaN
# 7   4 Prior to 1.1. 2007: Out-patient treatment of...    NaN
# 8   5 Prior to 1.1. 2007: Admission to vocational ...    NaN
# 9   6 The statistics on adult convictions (SUS) is...    NaN
# 10  Source: Federal Statistical Office - Criminal ...    NaN
# 11                                       © FSO – 2021    NaN
# 12                                                NaN    NaN
# 13  Information: Federal Statistical Office (FSO),...    NaN
#
#     Incarceration ¹\n\n\n\n(art. 64 SCC)  \
# ...

# %%
df_sheet_map.keys()
# Out:
# dict_keys(['Total', 'AG', 'AI', 'AR', 'BE', 'BL', 'BS', 'FR', 'GE', 'GL', 'GR', 'JU', 'LU', 'NE', 'NW', 'OW', 'SG', 'SH', 'SO', 'SZ', 'TG', 'TI', 'UR', 'VD', 'VS', 'ZG', 'ZH'])

# %%
for i in df_sheet_map.keys():
    df_all
# Out:
#    Adults: Convictions to a criminal measure, by type of measure, Switzerland  \
# 0                                                Year
# 1                                                2018
# 2                                                2019
# 3                                              2020 6
# 4   State of the Register of Criminal Conduct: 07....
# 5   ¹ Prior to 1.1. 2007: Incarceration of abnorma...
# 6   2 Prior to 1.1. 2007: In-patient measure for a...
# 7   3 Prior to 1.1. 2007: In-patient treatment of ...
# 8   4 Prior to 1.1. 2007: Out-patient treatment of...
# 9   5 Prior to 1.1. 2007: Admission to vocational ...
# 10  6 The statistics on adult convictions (SUS) is...
# 11  Source: Federal Statistical Office - Criminal ...
# 12                                       © FSO – 2021
# 13                                                NaN
# 14  Information: Federal Statistical Office (FSO),...
#
#    Unnamed: 1                            Unnamed: 2  \
# ...

# %%
df_sheet_map['VS'][1:4]
# Out:
#                                                 Year  Total  \
# 1                                               2019   24.0
# 2                                             2020 6   13.0
# 3  State of the Register of Criminal Conduct: 07....    NaN
#
#    Incarceration ¹\n\n\n\n(art. 64 SCC)  \
# 1                                   0.0
# 2                                   0.0
# 3                                   NaN
#
#    In-patient treatment of mental disorders 2\n\n\n(art. 59 SCC)  \
# 1                                               11.0
# 2                                                1.0
# 3                                                NaN
#
#    In-patient treatment of\naddiction 3\n\n\n(art. 60 SCC)  \
# 1                                                1.0
# 2                                                2.0
# 3                                                NaN
#
#    Out-patient treatment 4\n\n\n\n(art. 63 SCC)  \
# 1                                          12.0
# ...

# %%
for x in range(1,26):
    pd.read_excel('adult_convictions_ch_2018-2020.xlsx', sheet_name=x)
