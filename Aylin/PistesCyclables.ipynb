# %%
##voir l'évolution de l'aménagement des pistes cyclables depuis le debut du COVID-19

# %%
import pandas as pd

# %%
df = pd.read_csv('PistesCyclabesGE.csv', encoding ='latin-1', sep=';')

# %%
df.head()
# Out:
#    OBJECTID CODE_VOIE           NOM_VOIE TYPE_AMENAGEMENT REALISATION  \
# 0     59866       NaN                               Piste        2014
# 1     59869     17167  Avenue de la Paix            Bande        2001
# 2     59872     60160      Voie-Centrale            Bande        2012
# 3     59877       NaN                               Bande        2009
# 4     60182       NaN                               Bande        2009
#
#             CIRCUL2R      CIRCVOIT           AFFECTATION TOURNGAUCHE  \
# 0  unidirectionnelle  dans le sens  vélos + cyclomoteurs         NaN
# 1  unidirectionnelle  dans le sens  vélos + cyclomoteurs         NaN
# 2  unidirectionnelle  dans le sens  vélos + cyclomoteurs         NaN
# 3  unidirectionnelle  dans le sens  vélos + cyclomoteurs         NaN
# 4  unidirectionnelle  dans le sens  vélos + cyclomoteurs         NaN
#
#     SHAPE.LEN
# 0  146.446824
# 1  147.744894
# 2  179.124512
# 3   91.633661
# 4   23.622889

# %%
df["REALISATION"].value_counts()
# Out:
# 2011     357
#          230
# 2010     222
# 2009     198
# 2004     187
# 2014     180
# 1991     180
# 2019     174
# 2012     172
# 2008     171
# 2020     146
# 2016     136
# 1992     128
# 2015     127
# 1997     127
# 1998     121
# 2000     111
# 2018     109
# 1996     106
# 2013     100
# 2017      89
# 1993      85
# 1995      84
# ~2003     73
# 1957      72
# 2002      69
# 1994      67
# 1999      63
# 1987      63
# 1985      61
# ~2007     60
# 1988      60
# 2001      53
# 2003      52
# 1986      51
# 1989      46
# 2007      43
# 1990      43
# 2021      41
# 2005      35
# 1984      32
# 1982      25
# 2006      20
# ~2010     15
# 1960      15
# ~1998     13
# ~2000     10
# ~2011      8
# ~2013      7
# ?          5
# 1975       5
# 1983       5
# 1981       2
# ~2009      2
#  1998      1
# 1961       1
# ~1984      1
# ~1991      1
# Name: REALISATION, dtype: int64

# %%
columnsToShow = ['NOM_VOIE', 'TYPE_AMENAGEMENT', 'REALISATION']

df[columnsToShow].head()

df=df[columnsToShow]

# %%
df
# Out:
#                        NOM_VOIE TYPE_AMENAGEMENT REALISATION
# 0                                          Piste        2014
# 1             Avenue de la Paix            Bande        2001
# 2                 Voie-Centrale            Bande        2012
# 3                                          Bande        2009
# 4                                          Bande        2009
# 5                                          Bande        2009
# 6                                          Bande        2009
# 7                                          Bande        2009
# 8                                          Bande        2009
# 9                                          Bande        2014
# 10                                         Bande        2014
# 11                                         Bande        2014
# 12          Route de Saint-Loup            Bande        2014
# 13               Route de Crans            Bande        2014
# 14               Route de Crans            Bande        2014
# 15               Route de Crans            Bande        2014
# 16                                         Bande        2014
# 17                                           Sas        2014
# 18                                         Bande        2014
# 19                                         Bande        2014
# 20                                         Bande        2014
# 21                                    Contresens        2014
# 22                                 Dérogation 2R        2014
# 23         Route de Sous-Moulin            Bande       ~2003
# 24         Route de Sous-Moulin            Bande       ~2003
# 25         Route de Sous-Moulin            Bande       ~2003
# 26             Avenue de Thônex            Bande        2003
# 27             Avenue de Thônex            Bande        2003
# 28                                         Bande        2014
# 29            Route de Chevrens            Bande       ~2003
# ...                         ...              ...         ...
# 5607           Route de Veyrier            Bande        2009
# 5608                                       Bande        2016
# 5609                               Dérogation 2R         NaN
# 5610       Chemin du Bois-Brûlé            Bande         NaN
# 5611  Passerelle du Pré-Monnard            Piste
# 5612             Quai du Seujet              Sas        1996
# 5613        Rue de l' Industrie       Contresens        2010
# 5614          Rue de Moillebeau            Bande        1998
# 5615          Rue de Moillebeau            Bande        1998
# 5616                                       Bande        2019
# 5617            Rue de Malatrex            Bande        1992
# 5618           Route de Meinier            Bande        2008
# 5619           Route de Meinier            Bande        2008
# 5620             Route de Jussy            Piste        1991
# 5621             Route de Jussy            Piste        1991
# 5622             Route de Jussy            Piste        1991
# 5623             Route de Jussy            Piste        1991
# 5624             Route de Jussy            Piste        1991
# 5625             Route de Jussy            Piste        1991
# 5626             Route de Jussy            Piste        1991
# 5627             Route de Jussy            Piste        1991
# 5628             Route de Jussy            Piste        1991
# 5629             Route de Jussy            Piste        1991
# 5630             Route de Jussy            Piste        1991
# 5631             Route de Jussy            Piste        1991
# 5632             Route de Jussy            Piste        1991
# 5633             Route de Jussy            Piste        1991
# 5634             Route de Jussy            Piste        1991
# 5635             Route de Jussy            Piste        1991
# 5636             Route de Jussy            Piste        1991
#
# [5637 rows x 3 columns]

# %%
df['Commune'] = df.max(axis=1)

# %%
df
# Out:
#                        NOM_VOIE TYPE_AMENAGEMENT REALISATION  Commune
# 0                                          Piste        2014      NaN
# 1             Avenue de la Paix            Bande        2001      NaN
# 2                 Voie-Centrale            Bande        2012      NaN
# 3                                          Bande        2009      NaN
# 4                                          Bande        2009      NaN
# 5                                          Bande        2009      NaN
# 6                                          Bande        2009      NaN
# 7                                          Bande        2009      NaN
# 8                                          Bande        2009      NaN
# 9                                          Bande        2014      NaN
# 10                                         Bande        2014      NaN
# 11                                         Bande        2014      NaN
# 12          Route de Saint-Loup            Bande        2014      NaN
# 13               Route de Crans            Bande        2014      NaN
# 14               Route de Crans            Bande        2014      NaN
# 15               Route de Crans            Bande        2014      NaN
# 16                                         Bande        2014      NaN
# 17                                           Sas        2014      NaN
# 18                                         Bande        2014      NaN
# 19                                         Bande        2014      NaN
# 20                                         Bande        2014      NaN
# 21                                    Contresens        2014      NaN
# 22                                 Dérogation 2R        2014      NaN
# 23         Route de Sous-Moulin            Bande       ~2003      NaN
# 24         Route de Sous-Moulin            Bande       ~2003      NaN
# 25         Route de Sous-Moulin            Bande       ~2003      NaN
# 26             Avenue de Thônex            Bande        2003      NaN
# 27             Avenue de Thônex            Bande        2003      NaN
# 28                                         Bande        2014      NaN
# 29            Route de Chevrens            Bande       ~2003      NaN
# ...                         ...              ...         ...      ...
# 5607           Route de Veyrier            Bande        2009      NaN
# 5608                                       Bande        2016      NaN
# 5609                               Dérogation 2R         NaN      NaN
# 5610       Chemin du Bois-Brûlé            Bande         NaN      NaN
# 5611  Passerelle du Pré-Monnard            Piste                  NaN
# 5612             Quai du Seujet              Sas        1996      NaN
# 5613        Rue de l' Industrie       Contresens        2010      NaN
# 5614          Rue de Moillebeau            Bande        1998      NaN
# 5615          Rue de Moillebeau            Bande        1998      NaN
# 5616                                       Bande        2019      NaN
# 5617            Rue de Malatrex            Bande        1992      NaN
# 5618           Route de Meinier            Bande        2008      NaN
# 5619           Route de Meinier            Bande        2008      NaN
# 5620             Route de Jussy            Piste        1991      NaN
# 5621             Route de Jussy            Piste        1991      NaN
# 5622             Route de Jussy            Piste        1991      NaN
# 5623             Route de Jussy            Piste        1991      NaN
# 5624             Route de Jussy            Piste        1991      NaN
# 5625             Route de Jussy            Piste        1991      NaN
# 5626             Route de Jussy            Piste        1991      NaN
# 5627             Route de Jussy            Piste        1991      NaN
# 5628             Route de Jussy            Piste        1991      NaN
# 5629             Route de Jussy            Piste        1991      NaN
# 5630             Route de Jussy            Piste        1991      NaN
# 5631             Route de Jussy            Piste        1991      NaN
# 5632             Route de Jussy            Piste        1991      NaN
# 5633             Route de Jussy            Piste        1991      NaN
# 5634             Route de Jussy            Piste        1991      NaN
# 5635             Route de Jussy            Piste        1991      NaN
# 5636             Route de Jussy            Piste        1991      NaN
#
# [5637 rows x 4 columns]

# %%
df[ (df['Realisation'] == 2019) & (df['Type_amenagement'] == "Bande") ]

# %%
print(df["REALISATION"]==2019)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5607    False
# 5608    False
# 5609    False
# 5610    False
# 5611    False
# 5612    False
# 5613    False
# 5614    False
# 5615    False
# 5616    False
# 5617    False
# 5618    False
# 5619    False
# 5620    False
# 5621    False
# 5622    False
# 5623    False
# 5624    False
# 5625    False
# 5626    False
# 5627    False
# 5628    False
# 5629    False
# 5630    False
# 5631    False
# 5632    False
# 5633    False
# 5634    False
# 5635    False
# 5636    False
# Name: REALISATION, Length: 5637, dtype: bool
