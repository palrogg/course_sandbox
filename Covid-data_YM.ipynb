# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('https://www.bag.admin.ch/dam/bag/fr/dokumente/mt/k-und-i/aktuelle-ausbrueche-pandemien/2019-nCoV/covid-19-datengrundlage-lagebericht.xlsx.download.xlsx/200325_base%20de%20donn%C3%A9es_graphiques_COVID-19-rapport.xlsx', skiprows=6)

# %%
df.head()
# Out:
#         Date  Nombre de cas  Nombre de cas, cumulé  \
# 0 2020-02-24              1                      1
# 1 2020-02-25              1                      2
# 2 2020-02-26             10                     12
# 3 2020-02-27             10                     22
# 4 2020-02-28             10                     32
#
#    Nombre de cas hospitalisés  Nombre de cas hospitalisés, cumulé  \
# 0                           5                                   5
# 1                           4                                   9
# 2                           9                                  18
# 3                           4                                  22
# 4                           5                                  27
#
#    Nombre de décés  Nombre de décés, cumulé
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2              NaN                      NaN
# 3              NaN                      NaN
# 4              NaN                      NaN

# %%
df.dtypes
# Out:
# Date                                  datetime64[ns]
# Nombre de cas                                  int64
# Nombre de cas, cumulé                          int64
# Nombre de cas hospitalisés                     int64
# Nombre de cas hospitalisés, cumulé             int64
# Nombre de décés                              float64
# Nombre de décés, cumulé                      float64
# dtype: object

# %%
df.index = pd.to_datetime(df['Date'])

# %%
df['2020-02-28':'2020-03-16']['Nombre de cas'].sum()
# Out:
# 3752

# %%
df['2020-03-16':]['Nombre de cas'].sum()
# Out:
# 40417

# %%
plt.style.use('fivethirtyeight')

# %%
df['Nombre de cas'].plot(figsize=(14,9))

# %%
df['Nombre de cas'].hist(bins=20,figsize=(14,9))

# %%
df['Nombre de cas'].rolling('7d').mean().plot(figsize=(14,9))

# %%
df['Nombre de cas'].resample('W').sum().plot(figsize=(14,9))

# %%
df['Nombre de cas'].resample('W', label='left', loffset=pd.DateOffset(days=1)).sum()
# Out:
# Date
# 2020-02-24      56
# 2020-03-02     378
# 2020-03-09    2276
# 2020-03-16    6589
# 2020-03-23    7362
# 2020-03-30    6036
# 2020-04-06    3602
# 2020-04-13    1840
# 2020-04-20    1171
# 2020-04-27     699
# 2020-05-04     401
# 2020-05-11     230
# 2020-05-18     153
# 2020-05-25     126
# 2020-06-01      98
# 2020-06-08     140
# 2020-06-15     171
# 2020-06-22     354
# 2020-06-29     682
# 2020-07-06     632
# 2020-07-13     710
# 2020-07-20     824
# 2020-07-27    1152
# 2020-08-03    1092
# 2020-08-10    1573
# 2020-08-17    1856
# 2020-08-24    2090
# 2020-08-31     834
# Freq: W-MON, Name: Nombre de cas, dtype: int64
