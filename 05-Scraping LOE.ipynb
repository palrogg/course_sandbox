# %% [markdown]
# # Scraping
#
# Le scraping consiste à extraire des données de pages Web de manière automatique.
#
# La méthode la plus simple consiste à demander le code HTML de la page désirée et à utiliser sa structure pour accéder aux données intéressantes. Ces données peuvent contenir des liens vers d’autres pages à scraper.

# %%
# Ce module permet de faire des «requêtes»: donne-moi telle page Web
import requests

# Ce module sert à parcourir la structure d ela page
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Ici, on envoie une requête pour la page
response = requests.get('https://www.fhs.swiss/fre/watch_brands.html')

# %%
# Quel est le statut de la réponse? Si c’est un 404, la page n’a pas été trouvée
response
# Out:
# <Response [200]>

# %%
# On charge la page dans BeautifulSoup
doc = BeautifulSoup(response.text, 'html.parser')
print(doc.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    FH - Marques horlogÃ¨res
#   </title>
#   <link href="/favicon.ico" rel="icon" type="image/gif"/>
#   <link href="/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/styles-template.css?v=1.3" rel="stylesheet" type="text/css"/>
#   <!--<link href='http://fonts.googleapis.com/css?family=Oswald:400,300,700' rel='stylesheet' type='text/css'>-->
#   <link href="/css/Oswald.css" rel="stylesheet" type="text/css"/>
#   <script src="/js/jquery.min.321.js">
#   </script>
#   <script src="https://www.openindex.io/js/openindex.mxnunpyuoj3cvpf9.js" type="application/javascript">
#   </script>
#   <script type="text/javascript">
#    //<!--
# //document.oncontextmenu = new Function("return false");
# //-->
#   </script>
#  </head>
#  <body>
#   <div class="wrapper">
#    <div id="header">
#     <form action="search.html" method="get" name="form1">
#      <div id="top_header">
#       <input class="search-bt" id="oi-submit" title="send" type="submit" value=""/>
#       <input class="" id="oi-query" name="oi-query" placeholder="" type="text"/>
#       <ul>
#        <li>
#         <a href="contact.html">
#          Contact
#         </a>
#        </li>
#        <li>
#         <a href="/eng/watch_brands.html" title="English">
#          English
#         </a>
#        </li>
#        <li>
#         <a href="/jpn/watch_brands.html" title="Japanese">
#          æ¥æ¬èª
#         </a>
#        </li>
#        <li>
#         <a href="/zht/watch_brands.html" title="Traditional Chinese">
#          ç¹é«ä¸­æ
#         </a>
#        </li>
#        <li>
#         <a href="/zhs/watch_brands.html" title="Simplified Chinese">
#          ç®ä½ä¸­æ
#         </a>
#        </li>
#       </ul>
#      </div>
#     </form>
#     <a href="homepage.html">
#      <img class="logo_fh" src="/images/logo_fh_swiss.png"/>
#     </a>
#     <div id="slogan">
#      <span style="color:#0295da">
#       Site officiel
#      </span>
#      de lâhorlogerie suisse
#     </div>
#    </div>
#    <div id="nav">
#     <ul>
#      <li class="first">
#       <a href="homepage.html">
#        Accueil
#       </a>
#      </li>
#      <li>
#       <a href="swissmade.html">
#        Swiss made
#       </a>
#      </li>
#      <li>
#       <a href="stopthefakes.html">
#        Halte au faux!
#       </a>
#      </li>
#      <li>
#       <a href="statistics.html">
#        Statistiques
#       </a>
#      </li>
#      <li>
#       <a href="knowledge.html">
#        Connaissances
#       </a>
#      </li>
#      <li class="last">
#       <a href="watch_brands.html">
#        Liens horlogers
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="banner">
#     <img height="250" src="/images/banner_links.jpg" width="940"/>
#    </div>
#    <div id="container">
#     <div class="breadcrumb">
#      Accueil
#      <img src="/images/fleche_gris.png">
#       Liens et coordonnÃ©es
#       <img src="/images/fleche_gris.png">
#        Marques horlogÃ¨res
#       </img>
#      </img>
#     </div>
#     <h1 class="title">
#      Marques horlogÃ¨res
#     </h1>
#     <div id="content" style="width:100%;">
#      <div class="shaded" id="choice-letter">
#       <span style="color:#0098d4;">
#        A
#       </span>
#       <a href="?letter=B">
#        B
#       </a>
#       <a href="?letter=C">
#        C
#       </a>
#       <a href="?letter=D">
#        D
#       </a>
#       <a href="?letter=E">
#        E
#       </a>
#       <a href="?letter=F">
#        F
#       </a>
#       <a href="?letter=G">
#        G
#       </a>
#       <a href="?letter=H">
#        H
#       </a>
#       <a href="?letter=I">
#        I
#       </a>
#       <a href="?letter=J">
#        J
#       </a>
#       <a href="?letter=K">
#        K
#       </a>
#       <a href="?letter=L">
#        L
#       </a>
#       <a href="?letter=M">
#        M
#       </a>
#       <a href="?letter=N">
#        N
#       </a>
#       <a href="?letter=O">
#        O
#       </a>
#       <a href="?letter=P">
#        P
#       </a>
#       <a href="?letter=Q">
#        Q
#       </a>
#       <a href="?letter=R">
#        R
#       </a>
#       <a href="?letter=S">
#        S
#       </a>
#       <a href="?letter=T">
#        T
#       </a>
#       <a href="?letter=U">
#        U
#       </a>
#       <a href="?letter=V">
#        V
#       </a>
#       <a href="?letter=W">
#        W
#       </a>
#       <a href="?letter=X">
#        X
#       </a>
#       <a href="?letter=Y">
#        Y
#       </a>
#       <a href="?letter=Z">
#        Z
#       </a>
#      </div>
#      <div class="clear-both">
#      </div>
#      <!-- LOGO -->
#      <div class="div-logo shaded">
#       <a alt="Accord" href="http://www.accordwatch.com" target="_blank" title="Accord">
#        <img class="align-center no-border" src="/logos/503.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Adriatica" href="http://www.adriaticawatches.ch" target="_blank" title="Adriatica">
#        <img class="align-center no-border" src="/logos/377.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Advolat" href="http://www.advolat.com" target="_blank" title="Advolat">
#        <img class="align-center no-border" src="/logos/550.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="AÃ©ro Watch" href="http://www.aerowatch.com" target="_blank" title="AÃ©ro Watch">
#        <img class="align-center no-border" src="/logos/300.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Alatron" href="http://www.alatron.ch" target="_blank" title="Alatron">
#        <img class="align-center no-border" src="/logos/400.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="AMH" href="http://www.amhsa.ch" target="_blank" title="AMH">
#        <img class="align-center no-border" src="/logos/4.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Andersen" href="http://www.andersen-geneve.ch" target="_blank" title="Andersen">
#        <img class="align-center no-border" src="/logos/272.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="AndrÃ© Mouche" href="http://www.andremouche.swiss" target="_blank" title="AndrÃ© Mouche">
#        <img class="align-center no-border" src="/logos/438.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Armin Strom" href="http://www.arminstrom.com" target="_blank" title="Armin Strom">
#        <img class="align-center no-border" src="/logos/430.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Audemars Piguet" href="http://www.audemarspiguet.com" target="_blank" title="Audemars Piguet">
#        <img class="align-center no-border" src="/logos/10.gif"/>
#       </a>
#      </div>
#      <div class="div-logo shaded">
#       <a alt="Groupe Achor" href="http://www.groupe-achor.com" target="_blank" title="Groupe Achor">
#        <img class="align-center no-border" src="/logos/539.gif"/>
#       </a>
#      </div>
#      <div class="clear-both">
#      </div>
#     </div>
#     <div class="clear-both">
#     </div>
#    </div>
#   </div>
#   <div id="footer">
#    <div id="footer-content">
#     <div class="column_bottom">
#      <h2>
#       <a href="swissmade.html">
#        Swiss made
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="swissmade.html">
#        Base juridique
#       </a>
#       <br/>
#       <a href="strengthening.html">
#        Projet de renforcement
#       </a>
#       <br/>
#       <a href="swissness.html">
#        Swissness
#       </a>
#       <br/>
#       <a href="certification.html">
#        Marques de certification
#       </a>
#       <br/>
#       <a href="sip.html">
#        Signe d'identification du producteur
#       </a>
#      </p>
#      <hr/>
#      <p>
#      </p>
#     </div>
#     <div class="column_bottom">
#      <h2>
#       <a href="stopthefakes.html">
#        Halte au faux!
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="buy_counterfeit.html">
#        Acheter des contrefaçons?
#       </a>
#       <br/>
#       <a href="sell_counterfeit.html">
#        Vendre du faux?
#       </a>
#       <br/>
#       <a href="report-abuse.html">
#        Aidez-nous à lutter
#       </a>
#      </p>
#      <hr/>
#      <p>
#      </p>
#     </div>
#     <div class="column_bottom">
#      <h2>
#       <a href="statistics.html">
#        Statistiques
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="statistics.html">
#        Exportations mensuelles
#       </a>
#       <br/>
#       <a href="statistics.html">
#        Calendrier de publication
#       </a>
#      </p>
#      <hr/>
#      <p>
#      </p>
#      <p>
#      </p>
#     </div>
#     <div class="column_bottom">
#      <h2>
#       <a href="knowledge.html">
#        Connaissances
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="knowledge.html">
#        Technique
#       </a>
#       <br/>
#       <a href="knowledge.html">
#        Informations pratiques
#       </a>
#       <br/>
#       <a href="knowledge.html">
#        Histoire
#       </a>
#      </p>
#      <hr/>
#      <p>
#      </p>
#      <p>
#      </p>
#     </div>
#     <div class="column_bottom">
#      <h2>
#       <a href="links.html">
#        Liens et coordonnées
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="watch_brands.html">
#        Marques
#       </a>
#       <br/>
#       <a href="subcontractors_suppliers.html">
#        Sous-traitants
#       </a>
#       <br/>
#       <a href="organisations.html">
#        Organisations
#       </a>
#       <br/>
#       <a href="trade_press.html">
#        Presse professionnelle
#       </a>
#       <br/>
#       <a href="auctions.html">
#        Ventes aux enchères
#       </a>
#      </p>
#      <hr/>
#      <p>
#      </p>
#     </div>
#     <div class="column_bottom">
#      <h2>
#       <a href="revuefh.html">
#        Revue FH
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="revuefh.html">
#        Abonnement
#       </a>
#      </p>
#      <hr/>
#      <h2>
#       <a href="whoweare.html">
#        Qui sommes-nous ?
#       </a>
#      </h2>
#      <hr/>
#      <p>
#       <a href="members.html">
#        Devenir membre FH
#       </a>
#      </p>
#      <hr/>
#     </div>
#     <div class="copyright">
#      <p>
#       © Fédération de l'industrie horlogère suisse FH   1997 - 2021   Tous droits réservés   Logos et modèles sont protégés par leurs détenteurs respectifs
#      </p>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## Parcourir la structure de la page
# A partir de cette étape, la structure de la page est contenue dans notre variable `doc`.
#
# HTML est structuré par des balises, des mots-clés entourés des signes < et >:
#
# * un paragraphe est signalé par les balises `<p>` (au début) et `</p>` (à la fin)
# * le titre principal est entre les balises `<h1>` et `</h1>` (header 1)
# * un tableau est entre les balises `<table>` … `</table>`
# * une ligne de tableau est entre les balises `<tr>` … `</tr>` (table row)
# * une cellule de tableau est entre les balises `<td>` … `</td>` (table data)
#
# Nous pouvons demander à BeautifulSoup de nous chercher des balises HTML avec les fonctions:
#
# `find`: trouver la première balise correspondante
#
# `find_all`: trouver toutes les balises correspondantes

# %%
# Voici la liste des images

# %%
img = doc.find_all("img")
img
# Out:
# [<img class="logo_fh" src="/images/logo_fh_swiss.png"/>,
#  <img height="250" src="/images/banner_links.jpg" width="940"/>,
#  <img src="/images/fleche_gris.png"> Liens et coordonnÃ©es <img src="/images/fleche_gris.png"> Marques horlogÃ¨res</img></img>,
#  <img src="/images/fleche_gris.png"> Marques horlogÃ¨res</img>,
#  <img class="align-center no-border" src="/logos/503.gif"/>,
#  <img class="align-center no-border" src="/logos/377.gif"/>,
#  <img class="align-center no-border" src="/logos/550.gif"/>,
#  <img class="align-center no-border" src="/logos/300.gif"/>,
#  <img class="align-center no-border" src="/logos/400.gif"/>,
#  <img class="align-center no-border" src="/logos/4.gif"/>,
#  <img class="align-center no-border" src="/logos/272.gif"/>,
#  <img class="align-center no-border" src="/logos/438.gif"/>,
#  <img class="align-center no-border" src="/logos/430.gif"/>,
#  <img class="align-center no-border" src="/logos/10.gif"/>,
#  <img class="align-center no-border" src="/logos/539.gif"/>]

# %%
# Voici la liste des liens (75)

# %%
links = doc.find_all("a")
links
# Out:
# [<a href="contact.html">Contact</a>,
#  <a href="/eng/watch_brands.html" title="English">English</a>,
#  <a href="/jpn/watch_brands.html" title="Japanese">æ¥æ¬èª</a>,
#  <a href="/zht/watch_brands.html" title="Traditional Chinese">ç¹é«ä¸­æ</a>,
#  <a href="/zhs/watch_brands.html" title="Simplified Chinese">ç®ä½ä¸­æ</a>,
#  <a href="homepage.html"><img class="logo_fh" src="/images/logo_fh_swiss.png"/></a>,
#  <a href="homepage.html">Accueil</a>,
#  <a href="swissmade.html">Swiss made</a>,
#  <a href="stopthefakes.html">Halte au faux!</a>,
#  <a href="statistics.html">Statistiques</a>,
#  <a href="knowledge.html">Connaissances</a>,
#  <a href="watch_brands.html">Liens horlogers</a>,
#  <a href="?letter=B">B</a>,
#  <a href="?letter=C">C</a>,
#  <a href="?letter=D">D</a>,
#  <a href="?letter=E">E</a>,
#  <a href="?letter=F">F</a>,
#  <a href="?letter=G">G</a>,
#  <a href="?letter=H">H</a>,
#  <a href="?letter=I">I</a>,
#  <a href="?letter=J">J</a>,
#  <a href="?letter=K">K</a>,
#  <a href="?letter=L">L</a>,
#  <a href="?letter=M">M</a>,
#  <a href="?letter=N">N</a>,
#  <a href="?letter=O">O</a>,
#  <a href="?letter=P">P</a>,
#  <a href="?letter=Q">Q</a>,
#  <a href="?letter=R">R</a>,
#  <a href="?letter=S">S</a>,
#  <a href="?letter=T">T</a>,
#  <a href="?letter=U">U</a>,
#  <a href="?letter=V">V</a>,
#  <a href="?letter=W">W</a>,
#  <a href="?letter=X">X</a>,
#  <a href="?letter=Y">Y</a>,
#  <a href="?letter=Z">Z</a>,
#  <a alt="Accord" href="http://www.accordwatch.com" target="_blank" title="Accord"><img class="align-center no-border" src="/logos/503.gif"/></a>,
#  <a alt="Adriatica" href="http://www.adriaticawatches.ch" target="_blank" title="Adriatica"><img class="align-center no-border" src="/logos/377.gif"/></a>,
#  <a alt="Advolat" href="http://www.advolat.com" target="_blank" title="Advolat"><img class="align-center no-border" src="/logos/550.gif"/></a>,
#  <a alt="AÃ©ro Watch" href="http://www.aerowatch.com" target="_blank" title="AÃ©ro Watch"><img class="align-center no-border" src="/logos/300.gif"/></a>,
#  <a alt="Alatron" href="http://www.alatron.ch" target="_blank" title="Alatron"><img class="align-center no-border" src="/logos/400.gif"/></a>,
#  <a alt="AMH" href="http://www.amhsa.ch" target="_blank" title="AMH"><img class="align-center no-border" src="/logos/4.gif"/></a>,
#  <a alt="Andersen" href="http://www.andersen-geneve.ch" target="_blank" title="Andersen"><img class="align-center no-border" src="/logos/272.gif"/></a>,
#  <a alt="AndrÃ© Mouche" href="http://www.andremouche.swiss" target="_blank" title="AndrÃ© Mouche"><img class="align-center no-border" src="/logos/438.gif"/></a>,
#  <a alt="Armin Strom" href="http://www.arminstrom.com" target="_blank" title="Armin Strom"><img class="align-center no-border" src="/logos/430.gif"/></a>,
#  <a alt="Audemars Piguet" href="http://www.audemarspiguet.com" target="_blank" title="Audemars Piguet"><img class="align-center no-border" src="/logos/10.gif"/></a>,
#  <a alt="Groupe Achor" href="http://www.groupe-achor.com" target="_blank" title="Groupe Achor"><img class="align-center no-border" src="/logos/539.gif"/></a>,
#  <a href="swissmade.html">Swiss made</a>,
#  <a href="swissmade.html">Base juridique</a>,
#  <a href="strengthening.html">Projet de renforcement</a>,
#  <a href="swissness.html">Swissness</a>,
#  <a href="certification.html">Marques de certification</a>,
#  <a href="sip.html">Signe d'identification du producteur</a>,
#  <a href="stopthefakes.html">Halte au faux!</a>,
#  <a href="buy_counterfeit.html">Acheter des contrefaçons?</a>,
#  <a href="sell_counterfeit.html">Vendre du faux?</a>,
#  <a href="report-abuse.html">Aidez-nous à lutter</a>,
#  <a href="statistics.html">Statistiques</a>,
#  <a href="statistics.html">Exportations mensuelles</a>,
#  <a href="statistics.html">Calendrier de publication</a>,
#  <a href="knowledge.html">Connaissances</a>,
#  <a href="knowledge.html">Technique</a>,
#  <a href="knowledge.html">Informations pratiques</a>,
#  <a href="knowledge.html">Histoire</a>,
#  <a href="links.html">Liens et coordonnées</a>,
#  <a href="watch_brands.html">Marques</a>,
#  <a href="subcontractors_suppliers.html">Sous-traitants</a>,
#  <a href="organisations.html">Organisations</a>,
#  <a href="trade_press.html">Presse professionnelle</a>,
#  <a href="auctions.html">Ventes aux enchères</a>,
#  <a href="revuefh.html">Revue FH</a>,
#  <a href="revuefh.html">Abonnement</a>,
#  <a href="whoweare.html">Qui sommes-nous ?</a>,
#  <a href="members.html">Devenir membre FH</a>]

# %%
# Out:
# 75

# %% [markdown]
# ## Trouver les attributs
# Trouver des liens, c’est bien. Mais comment extraire l’URL vers lequel ils conduisent?
#
# La méthode `.get()` est faite pour ça: elle récupère les attributs d’une balise HTML, comme l’attribut «href» qui contient ces URL.

# %% [markdown]
# ## … et avec une boucle
# Mettons que nous voulons récupérer toutes les URL de notre menu:
# * avec une boucle `for`, on peut passer les liens en revue
# * la méthode `.get()` nous permettra de récupérer l’URL de chaque lien

# %%
for a in doc.select():
    print(a.get('href'))

# %% [markdown]
# ## Selecteurs
# Les balises html contiennent parfois les attributs **id** et/ou **class**. Concrètement, ça se présente par exemple comme ça:
#
# `<table id="resultats" class="bordered striped">`
#
# L’attribut **id** (identifiant) est unique: un seul élément le porte.
#
# L’attribut **class** (classes) peut être ajouté à plusieurs éléments.
#
# Les classes et identifiants servent à styliser la page: tels éléments ont une bordure rouge, un fond gris clair, etc. Ces instructions sont regroupées dans du [code CSS](https://www.w3.org/Style/Examples/011/firstcss.fr.html), un langage informatique qui définit la présentation du HTML.
#
# Dans le code CSS, on les éléments du HTML par des **sélecteurs**. En voici des exemples:
#
# `table
# #resultats
# table.striped
# .bordered`
#
# Tous ces sélecteurs renvoient à la `<table id="resultats" class="bordered striped">` donnée comme exemple plus haut. On peut donc cibler une balise HTML par son nom, par son id (en le précédent d’un "#") ou par une de ses classes.
#
# Pour trouver le sélecteur d’un élément qui vous intéresse, vous pouvez inspecter la page (cmd-alt-i dans Firefox ou Chrome), le repérer dans «Elements» grâce à la flèche tout à gauche, puis faire clic droit -> Copy -> CSS selector.
#
# Avec BeautifulSoup, on peut retrouver les éléments correspondants à un sélecteur grâce à la méthode:
#
# `.select('selecteur')`
#
# Cette méthode renvoie une liste, voici un exemple:

# %%
doc.select('.nav-menu a')

# %% [markdown]
# # Attributs et méthodes
#
# Mettez doc.find('p') dans la variable `test`, puis écrivez `test.` et appuyez sur tab en laissant votre curseur après le point. Quels attributs et méthodes apparaissent? Essayez-en quelques-uns.

# %% [markdown]
# Vous avez trouvez? Allez, je vous en donne trois:
# * `.string` donne le texte de la balise uniquement
# * `.text` donne le texte de la balise et de toutes les balises qu’elle contient
# * `.get()` permet d’obtenir un attribut précis, comme id, class, href
#
# Pour avoir des exemples clairs, on va charger une page spécialement préparée pour votre scraping.

# %%
response = requests.get('https://exemple.tcch.ch/scraping/')
doc = BeautifulSoup(response.content, 'html.parser')

# %%
# premier paragraphe
p = doc.find('p')
print('La balise et son contenu:', p)
print('Le contenu grâce à .string:', p.string)
print('Le contenu grâce à .text:', p.text)

# %% [markdown]
# Quelle différence entre `.string` et `.text`? On le comprend quand notre balise contient d’autres balises. C’est le cas du dernier paragraphe: il contient une balise `<em>`.

# %%
# dernier paragraphe
p = doc.select('p')[-1]
p

# %%
print('.string:', p.string)
print('.text:', p.text)

# %% [markdown]
# Quand une balise contient d’autres balises, `.string` renvoie donc **None**, tandis que `.text` renvoie tout le texte contenu dans la balise principale et les balises qu’elle contient.

# %% [markdown]
# ## A vous
# Qu’est-ce que `.string` et `.text` donnent comme résultat avec la table? Essayez!

# %%
Import pandas as pd

# %% [markdown]
# Le système que nous avons vu ne fonctionne pas pour certaines pages Web construites dynamiquement avec du JavaScript. Dans ce cas, on peut automatiser un navigateur tel que Chrome ou Firefox avec des outils comme [Selenium](https://pypi.org/project/selenium/). C’est nettement plus complexe que d’utiliser requests et BeautifulSoup.
