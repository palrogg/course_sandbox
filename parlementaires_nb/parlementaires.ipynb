# %% [markdown]
# <div style="text-align: right"> Prepared by Fanny Giroud for
# <a href="https://www.cfjm.ch/course/coder-pour-enqueter-niveau-1/">CFJM data workshop 2021</a> </div>

# %% [markdown]
# # Tips for Data Cleaning
#
# 1. Get column names
# 2. Recognize the data
# 3. Slicing the data
# 4. Check duplicates
# 5. NaN values
# 6. Check data types of variables
# 7. Working with dates
# 8. Get answers
# 9. Export results
# 10. More transformations

# %% [markdown]
# ## How many CH council members with age over 64 ?

# %%
import pandas as pd
import datetime
pd.options.display.max_columns = None

# %%
df = pd.read_excel('parlementaires.xlsx')

# %%
df.head()
# Out:
#    Active FirstName  LastName GenderAsString CantonName CantonAbbreviation  \
# 0   False  Giuseppe   a Marca              m    Grisons                 GR
# 1   False     Alois  Ab Yberg              m     Schwyz                 SZ
# 2   False     Fabio     Abate              m     Tessin                 TI
# 3   False     Fabio     Abate              m     Tessin                 TI
# 4   False     Fabio     Abate              m     Tessin                 TI
#
#          CouncilName                ParlGroupName ParlGroupAbbreviation  \
# 0  Conseil des Etats                       Centre                    MC
# 1   Conseil national  Groupe radical-démocratique                     R
# 2   Conseil national       Groupe radical-libéral                    RL
# 3   Conseil national       Groupe radical-libéral                     R
# 4  Conseil des Etats       Groupe libéral-radical                    RL
#
#                            PartyName PartyAbbreviation MaritalStatusText  \
# 0                      Conservateurs             Cons*               NaN
# 1  Parti radical-démocratique suisse               PRD               NaN
# 2  Parti radical-démocratique suisse               PRD               NaN
# 3  Parti radical-démocratique suisse               PRD               NaN
# 4          PLR.Les Libéraux-Radicaux               PLR               NaN
#
#   BirthPlace_City BirthPlace_Canton  \
# 0             NaN               NaN
# 1             NaN               NaN
# 2         Locarno            Tessin
# 3         Locarno            Tessin
# 4         Locarno            Tessin
#
#                                             Mandates DateJoining DateLeaving  \
# 0                                                NaN  01/12/1849  01/07/1851
# 1                                                NaN  03/12/1928  01/12/1935
# 2  incarichi esecutivi presso il comune di Locarn...  03/12/2007  04/12/2011
# 3  incarichi esecutivi presso il comune di Locarn...  25/09/2000  30/11/2003
# 4  incarichi esecutivi presso il comune di Locarn...  05/12/2011  29/11/2015
#
#    Citizenship DateOfBirth DateOfDeath
# 0  Soazza (GR)  29/07/1799  16/07/1866
# 1  Schwyz (SZ)  06/10/1878  17/10/1959
# 2  Cabbio (TI)  04/01/1966         NaN
# 3  Cabbio (TI)  04/01/1966         NaN
# 4  Cabbio (TI)  04/01/1966         NaN

# %% [markdown]
# #### 1. Get column names

# %%
list(df)
# Out:
# ['Active',
#  'FirstName',
#  'LastName',
#  'GenderAsString',
#  'CantonName',
#  'CantonAbbreviation',
#  'CouncilName',
#  'ParlGroupName',
#  'ParlGroupAbbreviation',
#  'PartyName',
#  'PartyAbbreviation',
#  'MaritalStatusText',
#  'BirthPlace_City',
#  'BirthPlace_Canton',
#  'Mandates',
#  'DateJoining',
#  'DateLeaving',
#  'Citizenship',
#  'DateOfBirth',
#  'DateOfDeath']

# %% [markdown]
# #### 2. Quick look to recognize the data

# %%
df['CouncilName'].value_counts()
# Out:
# Conseil national     4587
# Conseil des Etats    1481
# Conseil fédéral       350
# Name: CouncilName, dtype: int64

# %%
df['Active'].value_counts()
# Out:
# False    6150
# True      273
# Name: Active, dtype: int64

# %% [markdown]
# #### 3. Slice up the data

# %%
df = df[df['Active'] == True]

# %%
200 + 46 + 7
# Out:
# 253

# %%
len(df)

# Still 20 extra lines
# Out:
# 273

# %% [markdown]
# #### 4. Check for duplicates and drop duplicates

# %%
df[df.duplicated()]
# Out:
#       Active FirstName            LastName GenderAsString CantonName  \
# 2264    True    Andrea  Gmür-Schönenberger              f    Lucerne
# 4003    True       Leo              Müller              m    Lucerne
#
#      CantonAbbreviation        CouncilName                      ParlGroupName  \
# 2264                 LU  Conseil des Etats  Le groupe du centre. PDC-PEV-PBD.
# 4003                 LU   Conseil national  Le groupe du centre. PDC-PEV-PBD.
#
#      ParlGroupAbbreviation                        PartyName PartyAbbreviation  \
# 2264                 M-CEB  Parti démocrate-chrétien suisse               PDC
# 4003                 M-CEB  Parti démocrate-chrétien suisse               PDC
#
#      MaritalStatusText BirthPlace_City BirthPlace_Canton  \
# 2264               NaN         Wattwil           St-Gall
# 4003          marié(e)          Ruswil           Lucerne
#
#                                                Mandates DateJoining  \
# 2264  Legislative des Kantons Luzern: von 2007 bis 2...  02/12/2019
# 4003  Legislative des Kantons (Kantonsrat): 21. Apri...  02/12/2019
#
#      DateLeaving                             Citizenship DateOfBirth  \
# 2264         NaN  Lucerne (LU),Amden (SG),Kirchberg (SG)  17/07/1964
# 4003         NaN             Ruswil (LU),Schüpfheim (LU)  04/07/1958
#
#      DateOfDeath
# 2264         NaN
# 4003         NaN

# %%
df[df['LastName']=='Gmür-Schönenberger']
# Out:
#       Active FirstName            LastName GenderAsString CantonName  \
# 2263    True    Andrea  Gmür-Schönenberger              f    Lucerne
# 2264    True    Andrea  Gmür-Schönenberger              f    Lucerne
#
#      CantonAbbreviation        CouncilName                      ParlGroupName  \
# 2263                 LU  Conseil des Etats  Le groupe du centre. PDC-PEV-PBD.
# 2264                 LU  Conseil des Etats  Le groupe du centre. PDC-PEV-PBD.
#
#      ParlGroupAbbreviation                        PartyName PartyAbbreviation  \
# 2263                 M-CEB  Parti démocrate-chrétien suisse               PDC
# 2264                 M-CEB  Parti démocrate-chrétien suisse               PDC
#
#      MaritalStatusText BirthPlace_City BirthPlace_Canton  \
# 2263               NaN         Wattwil           St-Gall
# 2264               NaN         Wattwil           St-Gall
#
#                                                Mandates DateJoining  \
# 2263  Legislative des Kantons Luzern: von 2007 bis 2...  02/12/2019
# 2264  Legislative des Kantons Luzern: von 2007 bis 2...  02/12/2019
#
#      DateLeaving                             Citizenship DateOfBirth  \
# 2263         NaN  Lucerne (LU),Amden (SG),Kirchberg (SG)  17/07/1964
# 2264         NaN  Lucerne (LU),Amden (SG),Kirchberg (SG)  17/07/1964
#
#      DateOfDeath
# 2263         NaN
# 2264         NaN

# %%
df[df['LastName']=='Müller']
# Out:
#       Active FirstName LastName GenderAsString CantonName CantonAbbreviation  \
# 4002    True       Leo   Müller              m    Lucerne                 LU
# 4003    True       Leo   Müller              m    Lucerne                 LU
# 4004    True    Damian   Müller              m    Lucerne                 LU
#
#             CouncilName                      ParlGroupName  \
# 4002   Conseil national  Le groupe du centre. PDC-PEV-PBD.
# 4003   Conseil national  Le groupe du centre. PDC-PEV-PBD.
# 4004  Conseil des Etats             Groupe libéral-radical
#
#      ParlGroupAbbreviation                        PartyName PartyAbbreviation  \
# 4002                 M-CEB  Parti démocrate-chrétien suisse               PDC
# 4003                 M-CEB  Parti démocrate-chrétien suisse               PDC
# 4004                    RL        PLR.Les Libéraux-Radicaux               PLR
#
#      MaritalStatusText BirthPlace_City BirthPlace_Canton  \
# 4002          marié(e)          Ruswil           Lucerne
# 4003          marié(e)          Ruswil           Lucerne
# 4004               NaN        Ermensee           Lucerne
#
#                                                Mandates DateJoining  \
# 4002  Legislative des Kantons (Kantonsrat): 21. Apri...  02/12/2019
# 4003  Legislative des Kantons (Kantonsrat): 21. Apri...  02/12/2019
# 4004                                                NaN  02/12/2019
#
#      DateLeaving                  Citizenship DateOfBirth DateOfDeath
# 4002         NaN  Ruswil (LU),Schüpfheim (LU)  04/07/1958         NaN
# 4003         NaN  Ruswil (LU),Schüpfheim (LU)  04/07/1958         NaN
# 4004         NaN                Ermensee (LU)  25/10/1984         NaN

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 271

# %%
df[df['LastName']=='Gmür-Schönenberger']
# Out:
#       Active FirstName            LastName GenderAsString CantonName  \
# 2263    True    Andrea  Gmür-Schönenberger              f    Lucerne
#
#      CantonAbbreviation        CouncilName                      ParlGroupName  \
# 2263                 LU  Conseil des Etats  Le groupe du centre. PDC-PEV-PBD.
#
#      ParlGroupAbbreviation                        PartyName PartyAbbreviation  \
# 2263                 M-CEB  Parti démocrate-chrétien suisse               PDC
#
#      MaritalStatusText BirthPlace_City BirthPlace_Canton  \
# 2263               NaN         Wattwil           St-Gall
#
#                                                Mandates DateJoining  \
# 2263  Legislative des Kantons Luzern: von 2007 bis 2...  02/12/2019
#
#      DateLeaving                             Citizenship DateOfBirth  \
# 2263         NaN  Lucerne (LU),Amden (SG),Kirchberg (SG)  17/07/1964
#
#      DateOfDeath
# 2263         NaN

# %%
df['CouncilName'].value_counts()
# Out:
# Conseil national     200
# Conseil des Etats     46
# Conseil fédéral       24
# Name: CouncilName, dtype: int64

# %%
df[df['CouncilName'] == 'Conseil fédéral']

# DateJoining differs!
# Out:
#       Active  FirstName       LastName GenderAsString CantonName  \
# 122     True      Viola         Amherd              f     Valais
# 417     True      Alain         Berset              m   Fribourg
# 418     True      Alain         Berset              m   Fribourg
# 419     True      Alain         Berset              m   Fribourg
# 420     True      Alain         Berset              m   Fribourg
# 1033    True    Ignazio         Cassis              m     Tessin
# 3140    True      Karin  Keller-Sutter              f    St-Gall
# 3680    True       Ueli         Maurer              m     Zurich
# 3681    True       Ueli         Maurer              m     Zurich
# 3682    True       Ueli         Maurer              m     Zurich
# 3683    True       Ueli         Maurer              m     Zurich
# 3684    True       Ueli         Maurer              m     Zurich
# 3685    True       Ueli         Maurer              m     Zurich
# 3686    True       Ueli         Maurer              m     Zurich
# 3687    True       Ueli         Maurer              m     Zurich
# 4229    True        Guy       Parmelin              m       Vaud
# 4230    True        Guy       Parmelin              m       Vaud
# 4231    True        Guy       Parmelin              m       Vaud
# 5303    True  Simonetta      Sommaruga              f      Berne
# 5308    True  Simonetta      Sommaruga              f      Berne
# 5309    True  Simonetta      Sommaruga              f      Berne
# 5311    True  Simonetta      Sommaruga              f      Berne
# 5312    True  Simonetta      Sommaruga              f      Berne
# 5314    True  Simonetta      Sommaruga              f      Berne
#
#      CantonAbbreviation      CouncilName ParlGroupName ParlGroupAbbreviation  \
# 122                  VS  Conseil fédéral           NaN                   NaN
# 417                  FR  Conseil fédéral           NaN                   NaN
# 418                  FR  Conseil fédéral           NaN                   NaN
# 419                  FR  Conseil fédéral           NaN                   NaN
# 420                  FR  Conseil fédéral           NaN                   NaN
# 1033                 TI  Conseil fédéral           NaN                   NaN
# 3140                 SG  Conseil fédéral           NaN                   NaN
# 3680                 ZH  Conseil fédéral           NaN                   NaN
# 3681                 ZH  Conseil fédéral           NaN                   NaN
# 3682                 ZH  Conseil fédéral           NaN                   NaN
# 3683                 ZH  Conseil fédéral           NaN                   NaN
# 3684                 ZH  Conseil fédéral           NaN                   NaN
# 3685                 ZH  Conseil fédéral           NaN                   NaN
# 3686                 ZH  Conseil fédéral           NaN                   NaN
# 3687                 ZH  Conseil fédéral           NaN                   NaN
# 4229                 VD  Conseil fédéral           NaN                   NaN
# 4230                 VD  Conseil fédéral           NaN                   NaN
# 4231                 VD  Conseil fédéral           NaN                   NaN
# 5303                 BE  Conseil fédéral           NaN                   NaN
# 5308                 BE  Conseil fédéral           NaN                   NaN
# 5309                 BE  Conseil fédéral           NaN                   NaN
# 5311                 BE  Conseil fédéral           NaN                   NaN
# 5312                 BE  Conseil fédéral           NaN                   NaN
# 5314                 BE  Conseil fédéral           NaN                   NaN
#
#                             PartyName PartyAbbreviation MaritalStatusText  \
# 122   Parti démocrate-chrétien suisse               PDC               NaN
# 417           Parti socialiste suisse               PSS               NaN
# 418           Parti socialiste suisse               PSS               NaN
# 419           Parti socialiste suisse               PSS               NaN
# 420           Parti socialiste suisse               PSS               NaN
# 1033        PLR.Les Libéraux-Radicaux               PLR               NaN
# 3140        PLR.Les Libéraux-Radicaux               PLR          marié(e)
# 3680     Union Démocratique du Centre               UDC          marié(e)
# 3681     Union Démocratique du Centre               UDC          marié(e)
# 3682     Union Démocratique du Centre               UDC          marié(e)
# 3683     Union Démocratique du Centre               UDC          marié(e)
# 3684     Union Démocratique du Centre               UDC          marié(e)
# 3685     Union Démocratique du Centre               UDC          marié(e)
# 3686     Union Démocratique du Centre               UDC          marié(e)
# 3687     Union Démocratique du Centre               UDC          marié(e)
# 4229     Union Démocratique du Centre               UDC               NaN
# 4230     Union Démocratique du Centre               UDC               NaN
# 4231     Union Démocratique du Centre               UDC               NaN
# 5303          Parti socialiste suisse               PSS          marié(e)
# 5308          Parti socialiste suisse               PSS          marié(e)
# 5309          Parti socialiste suisse               PSS          marié(e)
# 5311          Parti socialiste suisse               PSS          marié(e)
# 5312          Parti socialiste suisse               PSS          marié(e)
# 5314          Parti socialiste suisse               PSS          marié(e)
#
#      BirthPlace_City BirthPlace_Canton  \
# 122           Brigue            Valais
# 417         Fribourg          Fribourg
# 418         Fribourg          Fribourg
# 419         Fribourg          Fribourg
# 420         Fribourg          Fribourg
# 1033           Sessa            Tessin
# 3140     Niederuzwil           St-Gall
# 3680   Wetzikon (ZH)            Zurich
# 3681   Wetzikon (ZH)            Zurich
# 3682   Wetzikon (ZH)            Zurich
# 3683   Wetzikon (ZH)            Zurich
# 3684   Wetzikon (ZH)            Zurich
# 3685   Wetzikon (ZH)            Zurich
# 3686   Wetzikon (ZH)            Zurich
# 3687   Wetzikon (ZH)            Zurich
# 4229         Bursins              Vaud
# 4230         Bursins              Vaud
# 4231         Bursins              Vaud
# 5303            Zoug              Zoug
# 5308            Zoug              Zoug
# 5309            Zoug              Zoug
# 5311            Zoug              Zoug
# 5312            Zoug              Zoug
# 5314            Zoug              Zoug
#
#                                                Mandates DateJoining  \
# 122   Exekutive der Gemeinde (Stadträtin) Brig-Glis:...  01/01/2019
# 417   Législatif communal (conseil général) de Belfa...  01/01/2012
# 418   Législatif communal (conseil général) de Belfa...  01/01/2017
# 419   Législatif communal (conseil général) de Belfa...  01/01/2018
# 420   Législatif communal (conseil général) de Belfa...  01/01/2019
# 1033  Legislativo del comune Collina d'Oro: da april...  01/11/2017
# 3140  Legislative der Gemeinde Wil (SG): von Januar ...  01/01/2019
# 3680  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2012
# 3681  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2013
# 3682  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2014
# 3683  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2016
# 3684  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2018
# 3685  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2019
# 3686  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2020
# 3687  Exekutive der Gemeinde (Gemeinderat Hinwil): v...  01/01/2009
# 4229                                                NaN  01/01/2016
# 4230                                                NaN  01/01/2019
# 4231                                                NaN  01/01/2020
# 5303  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/11/2010
# 5308  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/01/2014
# 5309  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/01/2015
# 5311  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/01/2016
# 5312  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/01/2019
# 5314  Exekutive der Gemeinde Köniz: Januar 1998 bis ...  01/01/2020
#
#      DateLeaving                                        Citizenship  \
# 122          NaN  Mund (VS),Brigue (VS),Zwischbergen (VS),Naters...
# 417   31/12/2016                               Misery-Courtion (FR)
# 418   31/12/2017                               Misery-Courtion (FR)
# 419   31/12/2018                               Misery-Courtion (FR)
# 420          NaN                               Misery-Courtion (FR)
# 1033         NaN                             Biasca (TI),Sessa (TI)
# 3140         NaN                      Kirchberg (SG),Jonschwil (SG)
# 3680  31/12/2012                         Hinwil (ZH),Adelboden (BE)
# 3681  31/12/2013                         Hinwil (ZH),Adelboden (BE)
# 3682  31/12/2015                         Hinwil (ZH),Adelboden (BE)
# 3683  31/12/2017                         Hinwil (ZH),Adelboden (BE)
# 3684  31/12/2018                         Hinwil (ZH),Adelboden (BE)
# 3685  31/12/2019                         Hinwil (ZH),Adelboden (BE)
# 3686         NaN                         Hinwil (ZH),Adelboden (BE)
# 3687  31/12/2011                         Hinwil (ZH),Adelboden (BE)
# 4229  31/12/2018                                       Bursins (VD)
# 4230  31/12/2019                                       Bursins (VD)
# 4231         NaN                                       Bursins (VD)
# 5303  31/12/2013                           Lugano (TI),Eggiwil (BE)
# 5308  31/12/2014                           Lugano (TI),Eggiwil (BE)
# 5309  31/12/2015                           Lugano (TI),Eggiwil (BE)
# 5311  31/12/2018                           Lugano (TI),Eggiwil (BE)
# 5312  31/12/2019                           Lugano (TI),Eggiwil (BE)
# 5314         NaN                           Lugano (TI),Eggiwil (BE)
#
#      DateOfBirth DateOfDeath
# 122   07/06/1962         NaN
# 417   09/04/1972         NaN
# 418   09/04/1972         NaN
# 419   09/04/1972         NaN
# 420   09/04/1972         NaN
# 1033  13/04/1961         NaN
# 3140  22/12/1963         NaN
# 3680  01/12/1950         NaN
# 3681  01/12/1950         NaN
# 3682  01/12/1950         NaN
# 3683  01/12/1950         NaN
# 3684  01/12/1950         NaN
# 3685  01/12/1950         NaN
# 3686  01/12/1950         NaN
# 3687  01/12/1950         NaN
# 4229  09/11/1959         NaN
# 4230  09/11/1959         NaN
# 4231  09/11/1959         NaN
# 5303  14/05/1960         NaN
# 5308  14/05/1960         NaN
# 5309  14/05/1960         NaN
# 5311  14/05/1960         NaN
# 5312  14/05/1960         NaN
# 5314  14/05/1960         NaN

# %% [markdown]
# #### 5. What are NaN values

# %%
# See columns with missing values

df[df.isnull().any(axis=1)]
# Out:
#       Active FirstName     LastName GenderAsString          CantonName  \
# 22      True  Jean-Luc        Addor              m              Valais
# 33      True   Andreas         Aebi              m               Berne
# 38      True  Matthias    Aebischer              m               Berne
# 66      True    Thomas       Aeschi              m                Zoug
# 114     True    Céline     Amaudruz              f              Genève
# ...      ...       ...          ...            ...                 ...
# 6268    True  Benedikt        Würth              m             St-Gall
# 6303    True   Roberto      Zanetti              m             Soleure
# 6342    True     Heidi    Z'graggen              f                 Uri
# 6375    True   Mathias        Zopfi              m              Glaris
# 6384    True     David  Zuberbühler              m  Appenzell Rh.-Ext.
#
#      CantonAbbreviation        CouncilName  \
# 22                   VS   Conseil national
# 33                   BE   Conseil national
# 38                   BE   Conseil national
# 66                   ZG   Conseil national
# 114                  GE   Conseil national
# ...                 ...                ...
# 6268                 SG  Conseil des Etats
# 6303                 SO  Conseil des Etats
# 6342                 UR  Conseil des Etats
# 6375                 GL  Conseil des Etats
# 6384                 AR   Conseil national
#
#                                  ParlGroupName ParlGroupAbbreviation  \
# 22    Groupe de l'Union démocratique du Centre                     V
# 33    Groupe de l'Union démocratique du Centre                     V
# 38                           Groupe socialiste                     S
# 66    Groupe de l'Union démocratique du Centre                     V
# 114   Groupe de l'Union démocratique du Centre                     V
# ...                                        ...                   ...
# 6268         Le groupe du centre. PDC-PEV-PBD.                 M-CEB
# 6303                         Groupe socialiste                     S
# 6342         Le groupe du centre. PDC-PEV-PBD.                 M-CEB
# 6375                          Groupe des Verts                     G
# 6384  Groupe de l'Union démocratique du Centre                     V
#
#                             PartyName PartyAbbreviation MaritalStatusText  \
# 22       Union Démocratique du Centre               UDC          marié(e)
# 33       Union Démocratique du Centre               UDC          marié(e)
# 38            Parti socialiste suisse               PSS               NaN
# 66       Union Démocratique du Centre               UDC               NaN
# 114      Union Démocratique du Centre               UDC               NaN
# ...                               ...               ...               ...
# 6268  Parti démocrate-chrétien suisse               PDC               NaN
# 6303          Parti socialiste suisse               PSS       célibataire
# 6342  Parti démocrate-chrétien suisse               PDC               NaN
# 6375          Parti écologiste suisse               PES               NaN
# 6384     Union Démocratique du Centre               UDC          marié(e)
#
#      BirthPlace_City   BirthPlace_Canton  \
# 22          Lausanne                Vaud
# 33          Burgdorf               Berne
# 38     Schwarzenburg               Berne
# 66              Zoug                Zoug
# 114           Genève              Genève
# ...              ...                 ...
# 6268        St. Gall             St-Gall
# 6303         Soleure             Soleure
# 6342         Silenen                 Uri
# 6375      Glarus Süd              Glaris
# 6384         Herisau  Appenzell Rh.-Ext.
#
#                                                Mandates DateJoining  \
# 22    Député au Grand Conseil: 2005-2015; Conseiller...  02/12/2019
# 33    Gemeindepräsident von Alchenstorf: von 1998 bi...  02/12/2019
# 38                                                  NaN  02/12/2019
# 66                        Zuger Kantonsrat: 2010 - 2012  02/12/2019
# 114   Organe législatif cantonal: depuis octobre 200...  02/12/2019
# ...                                                 ...         ...
# 6268  Regierungsrat des Kantons St. Gallen; Präsiden...  02/12/2019
# 6303  Gemeinderat: von 1977 bis April 1980; Gemeinde...  02/12/2019
# 6342         Regierungsrätin Kanton Uri: seit Juni 2004  02/12/2019
# 6375  Gemeinderat Glarus Süd: seit Januar 2010; Land...  02/12/2019
# 6384  Einwohnerrat (Legislative) der Gemeinde Herisa...  02/12/2019
#
#      DateLeaving                          Citizenship DateOfBirth DateOfDeath
# 22           NaN          Ste-Croix (VD),Savièse (VS)  22/04/1964         NaN
# 33           NaN                         Wynigen (BE)  26/11/1958         NaN
# 38           NaN                      Guggisberg (BE)  18/10/1967         NaN
# 66           NaN  Himmelried (SO),Baar (ZG),Bâle (BS)  13/01/1979         NaN
# 114          NaN                           Lutry (VD)  15/03/1979         NaN
# ...          ...                                  ...         ...         ...
# 6268         NaN       Berg (SG),Rapperswil-Jona (SG)  20/01/1968         NaN
# 6303         NaN                       Poschiavo (GR)  14/12/1954         NaN
# 6342         NaN                      Gurtnellen (UR)  01/02/1966         NaN
# 6375         NaN                      Glarus Süd (GL)  14/12/1983         NaN
# 6384         NaN                         Urnäsch (AR)  20/02/1979         NaN
#
# [271 rows x 20 columns]

# %%
len(df)
# Out:
# 271

# %%
df = df[df['DateLeaving'].isnull()]

# Delete multiple entries for Conseil fédéral
# nb # pour retirer les duplicates si le champ date de fin est complet, on ne garde que les NaN (on garde car la valeur est nulle.)

len(df)
# Out:
# 254

# %%
df = df[-df['CouncilName'].isnull()]
# nb # pour retirer la ligne avec CouncilName est NaN (on elimine car la valeur est nulle.)

# %%
len(df)
# Out:
# 253

# %%
200+46+7
# Out:
# 253

# %%
df['CouncilName'].value_counts()
# Out:
# Conseil national     200
# Conseil des Etats     46
# Conseil fédéral        7
# Name: CouncilName, dtype: int64

# %% [markdown]
# #### 6. Check data types of variables

# %%
# We're interested in calculating age

# %%
type("skdjh")
# là il dit que c'est un string chaîne de caractère
# Out:
# str

# %%
df.dtypes
# pour connaître la nature des données
# Out:
# Active                     bool
# FirstName                object
# LastName                 object
# GenderAsString           object
# CantonName               object
# CantonAbbreviation       object
# CouncilName              object
# ParlGroupName            object
# ParlGroupAbbreviation    object
# PartyName                object
# PartyAbbreviation        object
# MaritalStatusText        object
# BirthPlace_City          object
# BirthPlace_Canton        object
# Mandates                 object
# DateJoining              object
# DateLeaving              object
# Citizenship              object
# DateOfBirth              object
# DateOfDeath              object
# dtype: object

# %% [markdown]
# #### 7. Working with dates

# %%
# La library datetime a déjà été importée.
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2021, 6, 10, 11, 5, 10, 230919)

# %%
# Transform the data type to a date object

df['DateOfBirth'] = pd.to_datetime(df['DateOfBirth'])

df['DateOfBirth'].head()

# pour changer le format des dates de naissance
# Out:
# 22    1964-04-22
# 33    1958-11-26
# 38    1967-10-18
# 66    1979-01-13
# 114   1979-03-15
# Name: DateOfBirth, dtype: datetime64[ns]

# %%
# Calculate age en jour 

df['age'] = (now - df['DateOfBirth']) 

df['age'].head()
# Out:
# 22    20868 days 11:05:10.230919
# 33    22842 days 11:05:10.230919
# 38    19594 days 11:05:10.230919
# 66    15489 days 11:05:10.230919
# 114   15428 days 11:05:10.230919
# Name: age, dtype: timedelta64[ns]

# %%
# creation de la colonne age avec une division 365 pour avoir l'âge
df['age'] = df['age'].dt.days/365

df['age'].head()
# Out:
# 22     57.172603
# 33     62.580822
# 38     53.682192
# 66     42.435616
# 114    42.268493
# Name: age, dtype: float64

# %%
# la fonction 
df['age'] = round(df['age'])

df['age'].head()
# Out:
# 22     57.0
# 33     63.0
# 38     54.0
# 66     42.0
# 114    42.0
# Name: age, dtype: float64

# %%
df.sample()
# pour avoir un exemple
# Out:
#      Active FirstName  LastName GenderAsString CantonName CantonAbbreviation  \
# 114    True    Céline  Amaudruz              f     Genève                 GE
#
#           CouncilName                             ParlGroupName  \
# 114  Conseil national  Groupe de l'Union démocratique du Centre
#
#     ParlGroupAbbreviation                     PartyName PartyAbbreviation  \
# 114                     V  Union Démocratique du Centre               UDC
#
#     MaritalStatusText BirthPlace_City BirthPlace_Canton  \
# 114               NaN          Genève            Genève
#
#                                               Mandates DateJoining  \
# 114  Organe législatif cantonal: depuis octobre 200...  02/12/2019
#
#     DateLeaving Citizenship DateOfBirth DateOfDeath   age
# 114         NaN  Lutry (VD)  1979-03-15         NaN  42.0

# %% [markdown]
# #### 8. Get answers

# %%
len(df)
# Out:
# 253

# %%
len(df[df['age'] > 64])
#pour savoir qui a plus de 64
# Out:
# 19

# %%
# Proportion of council members older that 64

len(df[df['age'] > 64]) / len(df) * 100
# Out:
# 7.5098814229249005

# %%
# List of parlement members older than 64 yo (pour retirer conseil des états)

# %%
df = df[(df['CouncilName'] == 'Conseil national') | (df['CouncilName'] == 'Conseil des Etats')]
len(df)
# Out:
# 246

# %%
len(df[df['age'] > 64])
# Out:
# 18

# %%
len(df[df['age'] > 64]) / len(df) * 100
# Out:
# 7.317073170731707

# %%
df[df['age'] > 64]
# avec [] on a un tableau
# copie coller dans excel du résulat ou  faire un export
# Out:
#       Active    FirstName         LastName GenderAsString   CantonName  \
# 718     True       Daniel           Brélaz              m         Vaud
# 1599    True         Kurt            Egger              m    Thurgovie
# 1717    True    Christoph           Eymann              m   Bâle-Ville
# 1784    True     Laurence  Fehlmann Rielle              f       Genève
# 1887    True         Kurt            Fluri              m      Soleure
# 1943    True      Olivier         Français              m         Vaud
# 2180    True       Hannes          Germann              m  Schaffhouse
# 2260    True        Alois             Gmür              m       Schwyz
# 2371    True  Jean-Pierre             Grin              m         Vaud
# 2417    True    Jean-Paul         Gschwind              m         Jura
# 2687    True       Verena           Herzog              f    Thurgovie
# 4031    True      Martina             Munz              f  Schaffhouse
# 4511    True         Paul      Rechsteiner              m      St-Gall
# 5254    True        Heinz     Siegenthaler              m        Berne
# 5524    True         Hans          Stöckli              m        Berne
# 5538    True        Bruno           Storni              m       Tessin
# 5873    True       Albert           Vitali              m      Lucerne
# 6303    True      Roberto          Zanetti              m      Soleure
#
#      CantonAbbreviation        CouncilName  \
# 718                  VD   Conseil national
# 1599                 TG   Conseil national
# 1717                 BS   Conseil national
# 1784                 GE   Conseil national
# 1887                 SO   Conseil national
# 1943                 VD  Conseil des Etats
# 2180                 SH  Conseil des Etats
# 2260                 SZ   Conseil national
# 2371                 VD   Conseil national
# 2417                 JU   Conseil national
# 2687                 TG   Conseil national
# 4031                 SH   Conseil national
# 4511                 SG  Conseil des Etats
# 5254                 BE   Conseil national
# 5524                 BE  Conseil des Etats
# 5538                 TI   Conseil national
# 5873                 LU   Conseil national
# 6303                 SO  Conseil des Etats
#
#                                  ParlGroupName ParlGroupAbbreviation  \
# 718                           Groupe des Verts                     G
# 1599                          Groupe des Verts                     G
# 1717                    Groupe libéral-radical                    RL
# 1784                         Groupe socialiste                     S
# 1887                    Groupe libéral-radical                    RL
# 1943                    Groupe libéral-radical                    RL
# 2180  Groupe de l'Union démocratique du Centre                     V
# 2260         Le groupe du centre. PDC-PEV-PBD.                 M-CEB
# 2371  Groupe de l'Union démocratique du Centre                     V
# 2417         Le groupe du centre. PDC-PEV-PBD.                 M-CEB
# 2687  Groupe de l'Union démocratique du Centre                     V
# 4031                         Groupe socialiste                     S
# 4511                         Groupe socialiste                     S
# 5254         Le groupe du centre. PDC-PEV-PBD.                 M-CEB
# 5524                         Groupe socialiste                     S
# 5538                         Groupe socialiste                     S
# 5873                    Groupe libéral-radical                    RL
# 6303                         Groupe socialiste                     S
#
#                                 PartyName PartyAbbreviation MaritalStatusText  \
# 718               Parti écologiste suisse               PES               NaN
# 1599              Parti écologiste suisse               PES          marié(e)
# 1717              Parti libéral démocrate               PLD               NaN
# 1784              Parti socialiste suisse               PSS          marié(e)
# 1887            PLR.Les Libéraux-Radicaux               PLR               NaN
# 1943            PLR.Les Libéraux-Radicaux               PLR               NaN
# 2180         Union Démocratique du Centre               UDC               NaN
# 2260      Parti démocrate-chrétien suisse               PDC          marié(e)
# 2371         Union Démocratique du Centre               UDC               NaN
# 2417      Parti démocrate-chrétien suisse               PDC               NaN
# 2687         Union Démocratique du Centre               UDC          marié(e)
# 4031              Parti socialiste suisse               PSS               NaN
# 4511              Parti socialiste suisse               PSS          marié(e)
# 5254  Parti bourgeois-démocratique suisse               PBD               NaN
# 5524              Parti socialiste suisse               PSS          marié(e)
# 5538              Parti socialiste suisse               PSS          marié(e)
# 5873            PLR.Les Libéraux-Radicaux               PLR               NaN
# 6303              Parti socialiste suisse               PSS       célibataire
#
#            BirthPlace_City BirthPlace_Canton  \
# 718               Lausanne              Vaud
# 1599              St. Gall           St-Gall
# 1717                  Bâle        Bâle-Ville
# 1784       Chêne-Bougeries            Genève
# 1887               Soleure           Soleure
# 1943                  Metz               NaN
# 2180           Schaffhouse       Schaffhouse
# 2260            Einsiedeln            Schwyz
# 2371  Valeyres-sous-Rances              Vaud
# 2417            Porrentruy              Jura
# 2687            Winterthur            Zurich
# 4031                Zurich            Zurich
# 4511              St. Gall           St-Gall
# 5254                Bienne             Berne
# 5524             Wattenwil             Berne
# 5538               Gordola            Tessin
# 5873             Oberkirch           Lucerne
# 6303               Soleure           Soleure
#
#                                                Mandates DateJoining  \
# 718   Législatif communal: depuis 1986 jusqu'en 1989...  02/12/2019
# 1599  Legislative des Kantons Thurgau: vom Mai 2012 ...  02/12/2019
# 1717  Weiterer Bürgerrat: von 1989 bis 1991; Grosser...  02/12/2019
# 1784  Députée au Grand Conseil genevois: 1997-2009; ...  02/12/2019
# 1887  Exekutive der Gemeinde: seit Juni 1985; Legisl...  02/12/2019
# 1943  Législatif communal: Conseiller communal depui...  02/12/2019
# 2180  Exekutive der Gemeinde: Präsident von Januar 1...  02/12/2019
# 2260  Bezirksrat Einsiedeln: von 1986 bis 2000; Bezi...  02/12/2019
# 2371  Législatif communal: depuis avril 1967 jusqu'à...  02/12/2019
# 2417  Député au Parlement jurassien: depuis janvier ...  02/12/2019
# 2687  Kantonsrätin: von Februar 2007 bis Februar 201...  02/12/2019
# 4031                          Kantonsrätin: 2000 - 2018  02/12/2019
# 4511  Legislative der Gemeinde St. Gallen: von 1977 ...  02/12/2019
# 5254  Gemeinderat Rüti bei Büren: von Januar 1996 bi...  02/12/2019
# 5524  Legislative der Gemeinde: von August 1979 bis ...  02/12/2019
# 5538  Deputato Gran Consiglio Canton Ticino: da apri...  02/12/2019
# 5873  Gemeinderat/Sozialvorsteher Oberkirch: von Jan...  02/12/2019
# 6303  Gemeinderat: von 1977 bis April 1980; Gemeinde...  02/12/2019
#
#      DateLeaving                   Citizenship DateOfBirth DateOfDeath   age
# 718          NaN                    Lutry (VD)  1950-04-01         NaN  71.0
# 1599         NaN               Eggersriet (SG)  1956-01-19         NaN  65.0
# 1717         NaN                     Bâle (BS)  1951-01-15         NaN  70.0
# 1784         NaN                   Genève (GE)  1955-11-09         NaN  66.0
# 1887         NaN  Soleure (SO),Herbetswil (SO)  1955-08-19         NaN  66.0
# 1943         NaN                 Lausanne (VD)  1955-01-10         NaN  66.0
# 2180         NaN              Merishausen (SH)  1956-01-07         NaN  65.0
# 2260         NaN                    Amden (SG)  1955-03-04         NaN  66.0
# 2371         NaN      Belmont-sur-Yverdon (VD)  1947-03-16         NaN  74.0
# 2417         NaN                Damphreux (JU)  1952-10-31         NaN  69.0
# 2687         NaN  Homburg (TG),Winterthur (ZH)  1956-07-02         NaN  65.0
# 4031         NaN                   Sulgen (TG)  1955-12-26         NaN  66.0
# 4511         NaN                Appenzell (AI)  1952-08-26         NaN  69.0
# 5254         NaN                  Eggiwil (BE)  1955-11-10         NaN  66.0
# 5524         NaN                Wattenwil (BE)  1952-12-04         NaN  69.0
# 5538         NaN            Tenero-Contra (TI)  1954-08-17         NaN  67.0
# 5873         NaN     Oberkirch (LU),Elsau (ZH)  1955-06-26         NaN  66.0
# 6303         NaN                Poschiavo (GR)  1954-12-14         NaN  67.0

# %%
df[df['age'].idxmax() == df.index]
# Out:
#       Active    FirstName LastName GenderAsString CantonName  \
# 2371    True  Jean-Pierre     Grin              m       Vaud
#
#      CantonAbbreviation       CouncilName  \
# 2371                 VD  Conseil national
#
#                                  ParlGroupName ParlGroupAbbreviation  \
# 2371  Groupe de l'Union démocratique du Centre                     V
#
#                          PartyName PartyAbbreviation MaritalStatusText  \
# 2371  Union Démocratique du Centre               UDC               NaN
#
#            BirthPlace_City BirthPlace_Canton  \
# 2371  Valeyres-sous-Rances              Vaud
#
#                                                Mandates DateJoining  \
# 2371  Législatif communal: depuis avril 1967 jusqu'à...  02/12/2019
#
#      DateLeaving               Citizenship DateOfBirth DateOfDeath   age
# 2371         NaN  Belmont-sur-Yverdon (VD)  1947-03-16         NaN  74.0

# %%
df.sort_values( 'age')
# classement par age

# %%
df['age'].max()
# maximum dans la colonne age

# %% [markdown]
# #### 9. Export results

# %%
#df[df['age'] > 64][['FirstName', 'LastName', 'CantonName', 'CouncilName', 'age', 'DateOfBirth']].to_csv('export.csv')

# %%
df[df['age'] > 64][['FirstName', 'LastName', 'CantonName', 'CouncilName', 'age', 'DateOfBirth']].to_clipboard()

# %% [markdown]
# #### 10. More transformations

# %%
# Replace values
#df = df.replace("Vaud", "Waadt")

# Categorize
#df['group'] = 1
#df.loc[df['age'] > 64,'group'] = '2'

# Fill nan values with the value of your choice
#df.fillna()

# Change data type to numeric
#df['age'] = pd.to_numeric(df['age'])
