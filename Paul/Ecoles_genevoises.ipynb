# %% [markdown]
# ## Ecoles genevoises
#
# * Quelle commune a le plus d’élèves? Et d’écoles?
# * Où trouver quelle école coûte le plus cher par élève?
# * Comment les

# %%
import pandas as pd

# %%
df = pd.read_excel('cinemas-test.xlsx', skiprows=6)

# %%
df = pd.read_csv('DIP_ECOLE_PRIMAIRE_BATIMENT.csv', sep=';', encoding='latin-1')

# %%
# Supprimer la limite de nombre de lignes
pd.set_option('max_rows', None)

# Supprimer la limite de nombre de colonnes
pd.set_option('max_columns', None)

# %%
df['calcul'] = df['NB_EL_DERNIER_RELEVE'] - df['NB_1P_DERNIER_RELEVE']

# %%
df
# Out:
#                    COMMUNE               NOM_ECOLE  STATUT  \
# 0          Chêne-Bougeries                Montagne  Ouvert
# 1                   Chancy                  Chancy  Ouvert
# 2              Chêne-Bourg                Floraire  Ouvert
# 3                  Cologny                 Cologny  Ouvert
# 4              Genève-Cité            Cropettes CM  Ouvert
# 5              Genève-Cité                  Necker  Ouvert
# 6              Genève-Cité           Saint-Antoine  Ouvert
# 7        Genève-Eaux-Vives                  Roches  Ouvert
# 8        Genève-Eaux-Vives               Vollandes  Ouvert
# 9              Genève-Cité                  Seujet  Ouvert
# 10                Laconnex                Laconnex  Ouvert
# 11                    Onex         François-Chavaz   Fermé
# 12                   Lancy         Bachet-de-Pesay  Ouvert
# 13                  Meyrin                 Golette  Ouvert
# 14           Perly-Certoux           Perly-Certoux  Ouvert
# ...

# %%
df[df['COMMUNE'] != 'Chêne-Bougeries']
# Out:
#                    COMMUNE               NOM_ECOLE  STATUT  \
# 1                   Chancy                  Chancy  Ouvert
# 2              Chêne-Bourg                Floraire  Ouvert
# 3                  Cologny                 Cologny  Ouvert
# 4              Genève-Cité            Cropettes CM  Ouvert
# 5              Genève-Cité                  Necker  Ouvert
# 6              Genève-Cité           Saint-Antoine  Ouvert
# 7        Genève-Eaux-Vives                  Roches  Ouvert
# 8        Genève-Eaux-Vives               Vollandes  Ouvert
# 9              Genève-Cité                  Seujet  Ouvert
# 10                Laconnex                Laconnex  Ouvert
# 11                    Onex         François-Chavaz   Fermé
# 12                   Lancy         Bachet-de-Pesay  Ouvert
# 13                  Meyrin                 Golette  Ouvert
# 14           Perly-Certoux           Perly-Certoux  Ouvert
# 15   Genève-Petit-Saconnex               Vieusseux  Ouvert
# ...

# %%
df[50:150]
# Out:
#                    COMMUNE               NOM_ECOLE  STATUT  \
# 50                   Lancy                En Sauvy  Ouvert
# 51                      Gy                      Gy  Ouvert
# 52       Genève-Eaux-Vives              Eaux-Vives  Ouvert
# 53             Genève-Cité                 Grottes  Ouvert
# 54   Genève-Petit-Saconnex                Vidollet   Fermé
# 55      Genève-Plainpalais                   Dumas   Fermé
# 56      Genève-Plainpalais              Pré-Jérôme   Fermé
# 57      Genève-Plainpalais              Minoteries   Fermé
# 58                  Avully                 Gennecy   Fermé
# 59                    Onex            Bois-Carrien   Fermé
# 60       Genève-Eaux-Vives              Montchoisy  Ouvert
# 61   Genève-Petit-Saconnex        Pavillons d'Aïre   Fermé
# 62                Bellevue                Bellevue  Ouvert
# 63   Genève-Petit-Saconnex                  Europe  Ouvert
# 64         Pregny-Chambésy          Pregny-Valérie  Ouvert
# ...

# %%
df.sample(50)
# Out:
#                    COMMUNE               NOM_ECOLE  STATUT  \
# 62                Bellevue                Bellevue  Ouvert
# 46             Chêne-Bourg               De Haller  Ouvert
# 160                Vernier               Lignon CE  Ouvert
# 153                Carouge              Val d'Arve  Ouvert
# 113               Dardagny               La Plaine  Ouvert
# 39                    Onex            Onex Village  Ouvert
# 165            Vandoeuvres             Vandoeuvres  Ouvert
# 75                 Versoix             Courvoisier   Fermé
# 50                   Lancy                En Sauvy  Ouvert
# 40         Pregny-Chambésy         Pregny-Fontaine  Ouvert
# 181                 Thônex         Pavillon Mousse   Fermé
# 179        Plan-les-Ouates           Champ-Joly CE  Ouvert
# 174                Satigny          Satigny Mairie  Ouvert
# 127  Genève-Petit-Saconnex             Trembley CM  Ouvert
# 43                 Carouge         Jacques-Dalphin  Ouvert
# ...
