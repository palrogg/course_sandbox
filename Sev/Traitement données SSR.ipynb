# %%
import pandas as pd

df = pd.read_excel("ssr.xlsx", skiprows=3)

# %% [markdown]
# <b>Ce qu'on cherche</b>
# <br>Evolution de la politique de diffusion
# <br><br><b>Comment y parvenir</b>

# %%
df
# Out:
#                                            Unnamed: 0          1998  \
# 0                                               Total  50966.902500
# 1                                Premières diffusions  32657.739722
# 2                                             Fiction   6072.675278
# 3                        Divertissement non-fictionel   1126.245833
# 4                                         Information   9564.438333
# 5                                       Documentaires    274.577500
# 6                                               Sport   4539.648889
# 7           Formation / Sciences / Culture / Religion   1398.513333
# 8                                             Culture    491.566944
# 9                                           Formation    305.701667
# 10                                           Sciences    415.823333
# 11                                           Religion    185.421389
# 12                                            Musique    518.015556
# ...
