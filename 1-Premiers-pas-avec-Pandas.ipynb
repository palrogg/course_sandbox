# %% [markdown]
# # Premier pas avec Pandas
#
# Pandas est un module destiné à la manipulation de données. Il a été créé en 2008 et est très activement développé depuis. Il a été conçu au départ pour l’analyse de données financières.
#
# On l’importe comme n’importe quel module, et l’usage est de l’abrévier en «pd», grâce au mot-clé `as`:

# %%
import pandas as pd

# %% [markdown]
# Dans Excel, on parle de «feuilles de calcul». L’équivalent, dans Pandas, est un **DataFrame**, qu’on abrège **df**.
#
# Pour vous familiariser avec cet objet, on va ouvrir [des données de l’OFS obtenues sur STAT-TAB](http://www.pxweb.bfs.admin.ch/sq/a39f8d09-9e2b-4a58-b67a-51d22ebbe989):

# %%
df = pd.read_csv('couts-personnel-hautes-ecoles.csv')

# %% [markdown]
# Voyons à quoi ressemblent les 5 premières lignes

# %%
df.head()
# Out:
#    Année                            Prestation Nature de coûts  HETS-GE  \
# 0   2009                  Enseignement de base       Personnel  1845950
# 1   2009  Recherche appliquée et développement       Personnel   174791
# 2   2009                    Formation continue       Personnel   137429
# 3   2009               Prestations de services       Personnel   133224
# 4   2010                  Enseignement de base       Personnel  1787920
#
#    HEP-BEJUNE    HEP-VD   HEP-VS   HEP-FR
# 0    11603840  22487075  7449804  7679101
# 1     1254804   4998217  1163338  1655812
# 2     3937666   6571043   538089  1681846
# 3     1431853   2123045        0  3767684
# 4    14031903  20368249  7553247  9476562

# %% [markdown]
# ## Lister les valeurs d’une colonne
# Dans la colonne «Prestation», on voit que «Enseignement de base» apparaît au moins deux fois. Et si on regardait combien de fois apparaît chaque valeur de cette colonne?
# Pour ce faire, on utilise **`.value_counts()`**.

# %%
df['Prestation'].value_counts()
# Out:
# Enseignement de base                    11
# Formation continue                      11
# Recherche appliquée et développement    11
# Prestations de services                 11
# Name: Prestation, dtype: int64

# %% [markdown]
# ## Filtrer
#
# Regardons maintenant l’année 2019. Avec Pandas, ça se fait comme suit:

# %%
df[ df['Année'] == 2018 ]
# Out:
#     Année                            Prestation Nature de coûts  HETS-GE  \
# 36   2018                  Enseignement de base       Personnel  1932761
# 37   2018  Recherche appliquée et développement       Personnel   256710
# 38   2018                    Formation continue       Personnel   154446
# 39   2018               Prestations de services       Personnel   199456
#
#     HEP-BEJUNE    HEP-VD   HEP-VS   HEP-FR
# 36    13542045  41950755  8633675  9564308
# 37     2238965  12667583  1787200  2118586
# 38     3499772   7656946  1666031  1797675
# 39     1744989   2025399  2408620  1707231

# %%
df.max(axis=1)
# Out:
# 0     22487075
# 1      4998217
# 2      6571043
# 3      3767684
# 4     20368249
# 5      5581505
# 6      6037990
# 7      3133284
# 8     29579659
# 9      5949069
# 10     6233707
# 11     3260529
# 12    29088265
# 13     4298163
# 14     6031208
# 15     3379067
# 16    27579774
# 17     8595311
# 18     6829192
# 19     3172321
# 20    33173159
# 21    10058791
# 22     7206509
# 23     3015743
# 24    35680912
# 25    10589840
# 26     7218741
# 27     3040953
# 28    40957918
# 29    10823988
# 30     7541424
# 31     2657838
# 32    40114348
# 33    11608392
# 34     7512039
# 35     2567974
# 36    41950755
# 37    12667583
# 38     7656946
# 39     2408620
# 40    43207376
# 41    12663265
# 42     8691043
# 43     2676579
# dtype: int64

# %% [markdown]
# Autrement dit: on a demandé «Montre moi le dataframe pour lequel la colonne «Année» est égale à 2019».
#
# On peut choisir d’afficher uniquement certaines colonnes. Pour ce faire, on utilise une liste:

# %%
columnsToShow = ['Année', 'HEP-VD', 'HEP-FR']

# %%
df[columnsToShow].head()
# Out:
#    Année    HEP-VD   HEP-FR
# 0   2009  22487075  7679101
# 1   2009   4998217  1655812
# 2   2009   6571043  1681846
# 3   2009   2123045  3767684
# 4   2010  20368249  9476562

# %% [markdown]
# Mettons qu’on s’intéresse uniquement à 2018 et aux montants inférieurs à 100 000 à la HEP-VD. Pour combiner ces deux critères, on met les filtres dans des parenthèses et on utilise l’opérateur **`&`** pour  **and**.

# %%
df[ (df['Année'] == 2019) & (df['HEP-VD'] > 0) ]
# Out:
#     Année                            Prestation Nature de coûts  HETS-GE  \
# 40   2019                  Enseignement de base       Personnel  1994090
# 41   2019  Recherche appliquée et développement       Personnel   235679
# 42   2019                    Formation continue       Personnel   494971
# 43   2019               Prestations de services       Personnel   520148
#
#     HEP-BEJUNE    HEP-VD   HEP-VS   HEP-FR
# 40    12553917  43207376  9054637  9650727
# 41     2176814  12663265  1972288  2079828
# 42     3874482   8691043  1661413  2018726
# 43     2349377   2639705  2676579  1724585

# %% [markdown]
# ### Trouver le maximum
#
# Pandas trouve instantanément le maximum d’une ligne ou une colonne d’un jeu de données.
#
# Commençons par une colonne…

# %%
df['HEP-VD'].max()
# Out:
# 43207376

# %% [markdown]
# On peut aussi le demander pour toutes les colonnes:

# %%
df.max()
# Out:
# Année                                              2019
# Prestation         Recherche appliquée et développement
# Nature de coûts                               Personnel
# HETS-GE                                         2122376
# HEP-BEJUNE                                     14199474
# HEP-VD                                         43207376
# HEP-VS                                          9054637
# HEP-FR                                         10184870
# dtype: object

# %% [markdown]
# #### Et pour les lignes?
# Pour voir le maximum par ligne, on précise qu’on veut l’axe 1 (horizontal): `df.max(axis=1)`.

# %%
df.max(axis=1)
# Out:
# 0     22487075
# 1      4998217
# 2      6571043
# 3      3767684
# 4     20368249
# 5      5581505
# 6      6037990
# 7      3133284
# 8     29579659
# 9      5949069
# 10     6233707
# 11     3260529
# 12    29088265
# 13     4298163
# 14     6031208
# 15     3379067
# 16    27579774
# 17     8595311
# 18     6829192
# 19     3172321
# 20    33173159
# 21    10058791
# 22     7206509
# 23     3015743
# 24    35680912
# 25    10589840
# 26     7218741
# 27     3040953
# 28    40957918
# 29    10823988
# 30     7541424
# 31     2657838
# 32    40114348
# 33    11608392
# 34     7512039
# 35     2567974
# 36    41950755
# 37    12667583
# 38     7656946
# 39     2408620
# 40    43207376
# 41    12663265
# 42     8691043
# 43     2676579
# dtype: int64

# %% [markdown]
# Génial! Et si on mettait ça dans une colonne? Comme dans Excel, en fait…
#
# ## Ajouter une colonne
#
# Pandas vous permet d’ajouter une colonne plus ou moins de la même manière que vous donnez une valeur à une variable.

# %%
df['Maximum'] = df.max(axis=1)

# %%
df.head()
# Out:
#    Année                            Prestation Nature de coûts  HETS-GE  \
# 0   2009                  Enseignement de base       Personnel  1845950
# 1   2009  Recherche appliquée et développement       Personnel   174791
# 2   2009                    Formation continue       Personnel   137429
# 3   2009               Prestations de services       Personnel   133224
# 4   2010                  Enseignement de base       Personnel  1787920
#
#    HEP-BEJUNE    HEP-VD   HEP-VS   HEP-FR   Maximum
# 0    11603840  22487075  7449804  7679101  22487075
# 1     1254804   4998217  1163338  1655812   4998217
# 2     3937666   6571043   538089  1681846   6571043
# 3     1431853   2123045        0  3767684   3767684
# 4    14031903  20368249  7553247  9476562  20368249

# %% [markdown]
# ## Retirer une colonne
#
# Regardons la colonne «Nature de coûts» de plus près. La valeur est partout la même:

# %%
df['Nature de coûts'].value_counts()
# Out:
# Personnel    44
# Name: Nature de coûts, dtype: int64

# %% [markdown]
# Elle ne nous sert à rien. On peut l’éliminer avec **`del`**.
#
# Vous connaissez `del` pour les listes?

# %%
array = ['a', 'b']
del array[0]
array
# Out:
# ['b']

# %% [markdown]
# Pour les colonnes, c’est pareil:

# %%
del df['Nature de coûts']

# %% [markdown]
# ## Trier
# Dans Pandas, le tri se fait avec la méthode `.sort_values("nom_colonne_ici")`.

# %%
df.sort_values('Maximum')
# Out:
#     Année                            Prestation  HETS-GE  HEP-BEJUNE  \
# 39   2018               Prestations de services   199456     1744989
# 35   2017               Prestations de services   405726     1781042
# 31   2016               Prestations de services   301265     1646523
# 43   2019               Prestations de services   520148     2349377
# 23   2014               Prestations de services    96074     1429297
# 27   2015               Prestations de services    86708     1349543
# 7    2010               Prestations de services   100169     1419544
# 19   2013               Prestations de services   121384     1469451
# 11   2011               Prestations de services    81651     1443942
# 15   2012               Prestations de services   119333     1457441
# 3    2009               Prestations de services   133224     1431853
# 13   2012  Recherche appliquée et développement   254828     1551007
# 1    2009  Recherche appliquée et développement   174791     1254804
# 5    2010  Recherche appliquée et développement   149512     1502861
# 9    2011  Recherche appliquée et développement   228251     1537543
# 14   2012                    Formation continue   161025     5179649
# 6    2010                    Formation continue   146551     3804777
# 10   2011                    Formation continue   133821     4066746
# 2    2009                    Formation continue   137429     3937666
# 18   2013                    Formation continue   193299     4876828
# 22   2014                    Formation continue   160397     5048905
# 26   2015                    Formation continue   223118     4967718
# 34   2017                    Formation continue   341191     3358434
# 30   2016                    Formation continue   314951     4968285
# 38   2018                    Formation continue   154446     3499772
# 17   2013  Recherche appliquée et développement   218472     1795335
# 42   2019                    Formation continue   494971     3874482
# 21   2014  Recherche appliquée et développement   257229     1914540
# 25   2015  Recherche appliquée et développement   305237     1898223
# 29   2016  Recherche appliquée et développement   385855     2012681
# 33   2017  Recherche appliquée et développement   275926     2164651
# 41   2019  Recherche appliquée et développement   235679     2176814
# 37   2018  Recherche appliquée et développement   256710     2238965
# 4    2010                  Enseignement de base  1787920    14031903
# 0    2009                  Enseignement de base  1845950    11603840
# 16   2013                  Enseignement de base  2051730    13420288
# 12   2012                  Enseignement de base  1879788    13825057
# 8    2011                  Enseignement de base  1821890    14199474
# 20   2014                  Enseignement de base  2122376    12717387
# 24   2015                  Enseignement de base  2080177    13244598
# 32   2017                  Enseignement de base  1977361    13338050
# 28   2016                  Enseignement de base  2078340    12929548
# 36   2018                  Enseignement de base  1932761    13542045
# 40   2019                  Enseignement de base  1994090    12553917
#
#       HEP-VD   HEP-VS    HEP-FR   Maximum
# 39   2025399  2408620   1707231   2408620
# 35   2567974  2555640   1689654   2567974
# 31   1551425  2657838   1687785   2657838
# 43   2639705  2676579   1724585   2676579
# 23   1377381  3015743   2972196   3015743
# 27   1569324  2892061   3040953   3040953
# 7     858899        0   3133284   3133284
# 19   1051416        0   3172321   3172321
# 11   1683585        0   3260529   3260529
# 15   1148518        0   3379067   3379067
# 3    2123045        0   3767684   3767684
# 13   4298163   953634   1162974   4298163
# 1    4998217  1163338   1655812   4998217
# 5    5581505   967376   1042346   5581505
# 9    5949069   968652   1208909   5949069
# 14   6031208  1746074   1330662   6031208
# 6    6037990  1809025   1295660   6037990
# 10   6233707  1877448   1275166   6233707
# 2    6571043   538089   1681846   6571043
# 18   6829192  1886098   1982338   6829192
# 22   7206509  1706339   1917978   7206509
# 26   7218741  1693342   1761967   7218741
# 34   7512039  1674016   1962059   7512039
# 30   7541424  1693019   1915273   7541424
# 38   7656946  1666031   1797675   7656946
# 17   8595311  1014555   1137709   8595311
# 42   8691043  1661413   2018726   8691043
# 21  10058791   925649   1261784  10058791
# 25  10589840   942902   1270509  10589840
# 29  10823988  1216698   1163407  10823988
# 33  11608392  1465795   1168407  11608392
# 41  12663265  1972288   2079828  12663265
# 37  12667583  1787200   2118586  12667583
# 4   20368249  7553247   9476562  20368249
# 0   22487075  7449804   7679101  22487075
# 16  27579774  8342866   9933486  27579774
# 12  29088265  8453706  10184870  29088265
# 8   29579659  8023424   9812603  29579659
# 20  33173159  8458984   9638424  33173159
# 24  35680912  8037192   9517863  35680912
# 32  40114348  8059686   9600105  40114348
# 28  40957918  7985699   9823898  40957918
# 36  41950755  8633675   9564308  41950755
# 40  43207376  9054637   9650727  43207376

# %% [markdown]
# Que s’est-il passé? Par défaut, Pandas trie par ordre ascendant. Pour obtenir l’inverse, il faut préciser `ascending=False`:

# %%
df.sort_values('Maximum', ascending=False)
# Out:
#     Année                            Prestation  HETS-GE  HEP-BEJUNE  \
# 40   2019                  Enseignement de base  1994090    12553917
# 36   2018                  Enseignement de base  1932761    13542045
# 28   2016                  Enseignement de base  2078340    12929548
# 32   2017                  Enseignement de base  1977361    13338050
# 24   2015                  Enseignement de base  2080177    13244598
# 20   2014                  Enseignement de base  2122376    12717387
# 8    2011                  Enseignement de base  1821890    14199474
# 12   2012                  Enseignement de base  1879788    13825057
# 16   2013                  Enseignement de base  2051730    13420288
# 0    2009                  Enseignement de base  1845950    11603840
# 4    2010                  Enseignement de base  1787920    14031903
# 37   2018  Recherche appliquée et développement   256710     2238965
# 41   2019  Recherche appliquée et développement   235679     2176814
# 33   2017  Recherche appliquée et développement   275926     2164651
# 29   2016  Recherche appliquée et développement   385855     2012681
# 25   2015  Recherche appliquée et développement   305237     1898223
# 21   2014  Recherche appliquée et développement   257229     1914540
# 42   2019                    Formation continue   494971     3874482
# 17   2013  Recherche appliquée et développement   218472     1795335
# 38   2018                    Formation continue   154446     3499772
# 30   2016                    Formation continue   314951     4968285
# 34   2017                    Formation continue   341191     3358434
# 26   2015                    Formation continue   223118     4967718
# 22   2014                    Formation continue   160397     5048905
# 18   2013                    Formation continue   193299     4876828
# 2    2009                    Formation continue   137429     3937666
# 10   2011                    Formation continue   133821     4066746
# 6    2010                    Formation continue   146551     3804777
# 14   2012                    Formation continue   161025     5179649
# 9    2011  Recherche appliquée et développement   228251     1537543
# 5    2010  Recherche appliquée et développement   149512     1502861
# 1    2009  Recherche appliquée et développement   174791     1254804
# 13   2012  Recherche appliquée et développement   254828     1551007
# 3    2009               Prestations de services   133224     1431853
# 15   2012               Prestations de services   119333     1457441
# 11   2011               Prestations de services    81651     1443942
# 19   2013               Prestations de services   121384     1469451
# 7    2010               Prestations de services   100169     1419544
# 27   2015               Prestations de services    86708     1349543
# 23   2014               Prestations de services    96074     1429297
# 43   2019               Prestations de services   520148     2349377
# 31   2016               Prestations de services   301265     1646523
# 35   2017               Prestations de services   405726     1781042
# 39   2018               Prestations de services   199456     1744989
#
#       HEP-VD   HEP-VS    HEP-FR   Maximum
# 40  43207376  9054637   9650727  43207376
# 36  41950755  8633675   9564308  41950755
# 28  40957918  7985699   9823898  40957918
# 32  40114348  8059686   9600105  40114348
# 24  35680912  8037192   9517863  35680912
# 20  33173159  8458984   9638424  33173159
# 8   29579659  8023424   9812603  29579659
# 12  29088265  8453706  10184870  29088265
# 16  27579774  8342866   9933486  27579774
# 0   22487075  7449804   7679101  22487075
# 4   20368249  7553247   9476562  20368249
# 37  12667583  1787200   2118586  12667583
# 41  12663265  1972288   2079828  12663265
# 33  11608392  1465795   1168407  11608392
# 29  10823988  1216698   1163407  10823988
# 25  10589840   942902   1270509  10589840
# 21  10058791   925649   1261784  10058791
# 42   8691043  1661413   2018726   8691043
# 17   8595311  1014555   1137709   8595311
# 38   7656946  1666031   1797675   7656946
# 30   7541424  1693019   1915273   7541424
# 34   7512039  1674016   1962059   7512039
# 26   7218741  1693342   1761967   7218741
# 22   7206509  1706339   1917978   7206509
# 18   6829192  1886098   1982338   6829192
# 2    6571043   538089   1681846   6571043
# 10   6233707  1877448   1275166   6233707
# 6    6037990  1809025   1295660   6037990
# 14   6031208  1746074   1330662   6031208
# 9    5949069   968652   1208909   5949069
# 5    5581505   967376   1042346   5581505
# 1    4998217  1163338   1655812   4998217
# 13   4298163   953634   1162974   4298163
# 3    2123045        0   3767684   3767684
# 15   1148518        0   3379067   3379067
# 11   1683585        0   3260529   3260529
# 19   1051416        0   3172321   3172321
# 7     858899        0   3133284   3133284
# 27   1569324  2892061   3040953   3040953
# 23   1377381  3015743   2972196   3015743
# 43   2639705  2676579   1724585   2676579
# 31   1551425  2657838   1687785   2657838
# 35   2567974  2555640   1689654   2567974
# 39   2025399  2408620   1707231   2408620

# %% [markdown]
# ## Diviser
# Et si on rendait ça plus lisible en divisant par un million?

# %%
df['Maximum (millions)'] = df['Maximum'] / 1000000

# %%
df[['Année', 'Prestation', 'Maximum (millions)']].head()
# Out:
#    Année                            Prestation  Maximum (millions)
# 0   2009                  Enseignement de base           22.487075
# 1   2009  Recherche appliquée et développement            4.998217
# 2   2009                    Formation continue            6.571043
# 3   2009               Prestations de services            3.767684
# 4   2010                  Enseignement de base           20.368249

# %% [markdown]
# ## Arrondir
# Vous vous rappelez de `round()`? Ça marche aussi!

# %%
df['Maximum (millions)'] = round(df['Maximum (millions)'], 1)

df[['Année', 'Prestation', 'Maximum (millions)']].head()
# Out:
#    Année                            Prestation  Maximum (millions)
# 0   2009                  Enseignement de base                22.5
# 1   2009  Recherche appliquée et développement                 5.0
# 2   2009                    Formation continue                 6.6
# 3   2009               Prestations de services                 3.8
# 4   2010                  Enseignement de base                20.4

# %% [markdown]
# Déjà plus clair.
#
# Peut-être qu’on peut tout diviser par un million?

# %% [markdown]
# ## Exercice
#
# * Sélectionnez et affichez les données de 2018
#
# * Dans une autre cellule, sélectionnez la Formation continue uniquement (avec à nouveau toutes les années)
#
# * (En texte, sans programmation) Mettons que vous voulez faire un graphique. Quelles données auriez-vous envie de montrer?

# %%
df[ df['Année'] == 2018 ]
# Out:
#     Année                            Prestation Nature de coûts  HETS-GE  \
# 36   2018                  Enseignement de base       Personnel  1932761
# 37   2018  Recherche appliquée et développement       Personnel   256710
# 38   2018                    Formation continue       Personnel   154446
# 39   2018               Prestations de services       Personnel   199456
#
#     HEP-BEJUNE    HEP-VD   HEP-VS   HEP-FR
# 36    13542045  41950755  8633675  9564308
# 37     2238965  12667583  1787200  2118586
# 38     3499772   7656946  1666031  1797675
# 39     1744989   2025399  2408620  1707231

# %%
df[ df['Prestation'] == "Formation continue" ]
# Out:
#     Année          Prestation Nature de coûts  HETS-GE  HEP-BEJUNE   HEP-VD  \
# 2    2009  Formation continue       Personnel   137429     3937666  6571043
# 6    2010  Formation continue       Personnel   146551     3804777  6037990
# 10   2011  Formation continue       Personnel   133821     4066746  6233707
# 14   2012  Formation continue       Personnel   161025     5179649  6031208
# 18   2013  Formation continue       Personnel   193299     4876828  6829192
# 22   2014  Formation continue       Personnel   160397     5048905  7206509
# 26   2015  Formation continue       Personnel   223118     4967718  7218741
# 30   2016  Formation continue       Personnel   314951     4968285  7541424
# 34   2017  Formation continue       Personnel   341191     3358434  7512039
# 38   2018  Formation continue       Personnel   154446     3499772  7656946
# 42   2019  Formation continue       Personnel   494971     3874482  8691043
#
#      HEP-VS   HEP-FR
# 2    538089  1681846
# 6   1809025  1295660
# 10  1877448  1275166
# 14  1746074  1330662
# 18  1886098  1982338
# 22  1706339  1917978
# 26  1693342  1761967
# 30  1693019  1915273
# 34  1674016  1962059
# 38  1666031  1797675
# 42  1661413  2018726

# %%
df.sort_values('HETS-GE')
# Out:
#     Année                            Prestation Nature de coûts  HETS-GE  \
# 11   2011               Prestations de services       Personnel    81651
# 27   2015               Prestations de services       Personnel    86708
# 23   2014               Prestations de services       Personnel    96074
# 7    2010               Prestations de services       Personnel   100169
# 15   2012               Prestations de services       Personnel   119333
# 19   2013               Prestations de services       Personnel   121384
# 3    2009               Prestations de services       Personnel   133224
# 10   2011                    Formation continue       Personnel   133821
# 2    2009                    Formation continue       Personnel   137429
# 6    2010                    Formation continue       Personnel   146551
# 5    2010  Recherche appliquée et développement       Personnel   149512
# 38   2018                    Formation continue       Personnel   154446
# 22   2014                    Formation continue       Personnel   160397
# 14   2012                    Formation continue       Personnel   161025
# 1    2009  Recherche appliquée et développement       Personnel   174791
# 18   2013                    Formation continue       Personnel   193299
# 39   2018               Prestations de services       Personnel   199456
# 17   2013  Recherche appliquée et développement       Personnel   218472
# 26   2015                    Formation continue       Personnel   223118
# 9    2011  Recherche appliquée et développement       Personnel   228251
# 41   2019  Recherche appliquée et développement       Personnel   235679
# 13   2012  Recherche appliquée et développement       Personnel   254828
# 37   2018  Recherche appliquée et développement       Personnel   256710
# 21   2014  Recherche appliquée et développement       Personnel   257229
# 33   2017  Recherche appliquée et développement       Personnel   275926
# 31   2016               Prestations de services       Personnel   301265
# 25   2015  Recherche appliquée et développement       Personnel   305237
# 30   2016                    Formation continue       Personnel   314951
# 34   2017                    Formation continue       Personnel   341191
# 29   2016  Recherche appliquée et développement       Personnel   385855
# 35   2017               Prestations de services       Personnel   405726
# 42   2019                    Formation continue       Personnel   494971
# 43   2019               Prestations de services       Personnel   520148
# 4    2010                  Enseignement de base       Personnel  1787920
# 8    2011                  Enseignement de base       Personnel  1821890
# 0    2009                  Enseignement de base       Personnel  1845950
# 12   2012                  Enseignement de base       Personnel  1879788
# 36   2018                  Enseignement de base       Personnel  1932761
# 32   2017                  Enseignement de base       Personnel  1977361
# 40   2019                  Enseignement de base       Personnel  1994090
# 16   2013                  Enseignement de base       Personnel  2051730
# 28   2016                  Enseignement de base       Personnel  2078340
# 24   2015                  Enseignement de base       Personnel  2080177
# 20   2014                  Enseignement de base       Personnel  2122376
#
#     HEP-BEJUNE    HEP-VD   HEP-VS    HEP-FR
# 11     1443942   1683585        0   3260529
# 27     1349543   1569324  2892061   3040953
# 23     1429297   1377381  3015743   2972196
# 7      1419544    858899        0   3133284
# 15     1457441   1148518        0   3379067
# 19     1469451   1051416        0   3172321
# 3      1431853   2123045        0   3767684
# 10     4066746   6233707  1877448   1275166
# 2      3937666   6571043   538089   1681846
# 6      3804777   6037990  1809025   1295660
# 5      1502861   5581505   967376   1042346
# 38     3499772   7656946  1666031   1797675
# 22     5048905   7206509  1706339   1917978
# 14     5179649   6031208  1746074   1330662
# 1      1254804   4998217  1163338   1655812
# 18     4876828   6829192  1886098   1982338
# 39     1744989   2025399  2408620   1707231
# 17     1795335   8595311  1014555   1137709
# 26     4967718   7218741  1693342   1761967
# 9      1537543   5949069   968652   1208909
# 41     2176814  12663265  1972288   2079828
# 13     1551007   4298163   953634   1162974
# 37     2238965  12667583  1787200   2118586
# 21     1914540  10058791   925649   1261784
# 33     2164651  11608392  1465795   1168407
# 31     1646523   1551425  2657838   1687785
# 25     1898223  10589840   942902   1270509
# 30     4968285   7541424  1693019   1915273
# 34     3358434   7512039  1674016   1962059
# 29     2012681  10823988  1216698   1163407
# 35     1781042   2567974  2555640   1689654
# 42     3874482   8691043  1661413   2018726
# 43     2349377   2639705  2676579   1724585
# 4     14031903  20368249  7553247   9476562
# 8     14199474  29579659  8023424   9812603
# 0     11603840  22487075  7449804   7679101
# 12    13825057  29088265  8453706  10184870
# 36    13542045  41950755  8633675   9564308
# 32    13338050  40114348  8059686   9600105
# 40    12553917  43207376  9054637   9650727
# 16    13420288  27579774  8342866   9933486
# 28    12929548  40957918  7985699   9823898
# 24    13244598  35680912  8037192   9517863
# 20    12717387  33173159  8458984   9638424

# %%
df.sort_values('HETS-GE', ascending=False)
# Out:
#     Année                            Prestation Nature de coûts  HETS-GE  \
# 20   2014                  Enseignement de base       Personnel  2122376
# 24   2015                  Enseignement de base       Personnel  2080177
# 28   2016                  Enseignement de base       Personnel  2078340
# 16   2013                  Enseignement de base       Personnel  2051730
# 40   2019                  Enseignement de base       Personnel  1994090
# 32   2017                  Enseignement de base       Personnel  1977361
# 36   2018                  Enseignement de base       Personnel  1932761
# 12   2012                  Enseignement de base       Personnel  1879788
# 0    2009                  Enseignement de base       Personnel  1845950
# 8    2011                  Enseignement de base       Personnel  1821890
# 4    2010                  Enseignement de base       Personnel  1787920
# 43   2019               Prestations de services       Personnel   520148
# 42   2019                    Formation continue       Personnel   494971
# 35   2017               Prestations de services       Personnel   405726
# 29   2016  Recherche appliquée et développement       Personnel   385855
# 34   2017                    Formation continue       Personnel   341191
# 30   2016                    Formation continue       Personnel   314951
# 25   2015  Recherche appliquée et développement       Personnel   305237
# 31   2016               Prestations de services       Personnel   301265
# 33   2017  Recherche appliquée et développement       Personnel   275926
# 21   2014  Recherche appliquée et développement       Personnel   257229
# 37   2018  Recherche appliquée et développement       Personnel   256710
# 13   2012  Recherche appliquée et développement       Personnel   254828
# 41   2019  Recherche appliquée et développement       Personnel   235679
# 9    2011  Recherche appliquée et développement       Personnel   228251
# 26   2015                    Formation continue       Personnel   223118
# 17   2013  Recherche appliquée et développement       Personnel   218472
# 39   2018               Prestations de services       Personnel   199456
# 18   2013                    Formation continue       Personnel   193299
# 1    2009  Recherche appliquée et développement       Personnel   174791
# 14   2012                    Formation continue       Personnel   161025
# 22   2014                    Formation continue       Personnel   160397
# 38   2018                    Formation continue       Personnel   154446
# 5    2010  Recherche appliquée et développement       Personnel   149512
# 6    2010                    Formation continue       Personnel   146551
# 2    2009                    Formation continue       Personnel   137429
# 10   2011                    Formation continue       Personnel   133821
# 3    2009               Prestations de services       Personnel   133224
# 19   2013               Prestations de services       Personnel   121384
# 15   2012               Prestations de services       Personnel   119333
# 7    2010               Prestations de services       Personnel   100169
# 23   2014               Prestations de services       Personnel    96074
# 27   2015               Prestations de services       Personnel    86708
# 11   2011               Prestations de services       Personnel    81651
#
#     HEP-BEJUNE    HEP-VD   HEP-VS    HEP-FR
# 20    12717387  33173159  8458984   9638424
# 24    13244598  35680912  8037192   9517863
# 28    12929548  40957918  7985699   9823898
# 16    13420288  27579774  8342866   9933486
# 40    12553917  43207376  9054637   9650727
# 32    13338050  40114348  8059686   9600105
# 36    13542045  41950755  8633675   9564308
# 12    13825057  29088265  8453706  10184870
# 0     11603840  22487075  7449804   7679101
# 8     14199474  29579659  8023424   9812603
# 4     14031903  20368249  7553247   9476562
# 43     2349377   2639705  2676579   1724585
# 42     3874482   8691043  1661413   2018726
# 35     1781042   2567974  2555640   1689654
# 29     2012681  10823988  1216698   1163407
# 34     3358434   7512039  1674016   1962059
# 30     4968285   7541424  1693019   1915273
# 25     1898223  10589840   942902   1270509
# 31     1646523   1551425  2657838   1687785
# 33     2164651  11608392  1465795   1168407
# 21     1914540  10058791   925649   1261784
# 37     2238965  12667583  1787200   2118586
# 13     1551007   4298163   953634   1162974
# 41     2176814  12663265  1972288   2079828
# 9      1537543   5949069   968652   1208909
# 26     4967718   7218741  1693342   1761967
# 17     1795335   8595311  1014555   1137709
# 39     1744989   2025399  2408620   1707231
# 18     4876828   6829192  1886098   1982338
# 1      1254804   4998217  1163338   1655812
# 14     5179649   6031208  1746074   1330662
# 22     5048905   7206509  1706339   1917978
# 38     3499772   7656946  1666031   1797675
# 5      1502861   5581505   967376   1042346
# 6      3804777   6037990  1809025   1295660
# 2      3937666   6571043   538089   1681846
# 10     4066746   6233707  1877448   1275166
# 3      1431853   2123045        0   3767684
# 19     1469451   1051416        0   3172321
# 15     1457441   1148518        0   3379067
# 7      1419544    858899        0   3133284
# 23     1429297   1377381  3015743   2972196
# 27     1349543   1569324  2892061   3040953
# 11     1443942   1683585        0   3260529

# %%
df[['Année']]
# Out:
#     Année
# 0    2009
# 1    2009
# 2    2009
# 3    2009
# 4    2010
# 5    2010
# 6    2010
# 7    2010
# 8    2011
# 9    2011
# 10   2011
# 11   2011
# 12   2012
# 13   2012
# 14   2012
# 15   2012
# 16   2013
# 17   2013
# 18   2013
# 19   2013
# 20   2014
# 21   2014
# 22   2014
# 23   2014
# 24   2015
# 25   2015
# 26   2015
# 27   2015
# 28   2016
# 29   2016
# 30   2016
# 31   2016
# 32   2017
# 33   2017
# 34   2017
# 35   2017
# 36   2018
# 37   2018
# 38   2018
# 39   2018
# 40   2019
# 41   2019
# 42   2019
# 43   2019

# %% [markdown]
# ### Cellule de texte
# Vous pouvez répondre à la 3e question ici
#
# …
