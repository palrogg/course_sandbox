# %%
import pandas as pd

# %%
df = pd.read_csv('SYB63_314_202009_Internet_Usage.csv', skiprows=1)

# %%
df.head(142)
# Out:
#      Region/Country/Area                     Unnamed: 1  Year  \
# 0                      1  Total, all countries or areas  2000
# 1                      1  Total, all countries or areas  2005
# 2                      1  Total, all countries or areas  2010
# 3                      1  Total, all countries or areas  2015
# 4                      1  Total, all countries or areas  2016
# ..                   ...                            ...   ...
# 137                    9                        Oceania  2017
# 138                   53      Australia and New Zealand  2000
# 139                   53      Australia and New Zealand  2005
# 140                   53      Australia and New Zealand  2010
# 141                   53      Australia and New Zealand  2015
#
#                                            Series    Value Footnotes  \
# 0    Percentage of individuals using the internet   6.5316       NaN
# 1    Percentage of individuals using the internet  15.6777       NaN
# ...

# %%
df.columns
# Out:
# Index(['Region/Country/Area', 'Unnamed: 1', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df [['Region/Country/Area', 'Unnamed: 1', 'Year', 'Series', 'Value']]
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2000
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2016
# ...                   ...                            ...   ...
# 1464                  716                       Zimbabwe  2005
# 1465                  716                       Zimbabwe  2010
# 1466                  716                       Zimbabwe  2015
# 1467                  716                       Zimbabwe  2016
# 1468                  716                       Zimbabwe  2017
#
#                                             Series    Value
# 0     Percentage of individuals using the internet   6.5316
# 1     Percentage of individuals using the internet  15.6777
# ...

# %% [markdown]
# les 142 lignes portent sur des zones consolidées
# A partir de la 138, par pays // Australia

# %%
df2 = pd.read_csv('SYB63_315_202009_Water_and_Sanitation_Services.csv', skiprows=1)

# %%
df2.head(262)
# Out:
#      Region/Country/Area                     Unnamed: 1  Year  \
# 0                      1  Total, all countries or areas  2005
# 1                      1  Total, all countries or areas  2005
# 2                      1  Total, all countries or areas  2005
# 3                      1  Total, all countries or areas  2005
# 4                      1  Total, all countries or areas  2005
# ..                   ...                            ...   ...
# 257                    9                        Oceania  2017
# 258                   53      Australia and New Zealand  2005
# 259                   53      Australia and New Zealand  2005
# 260                   53      Australia and New Zealand  2010
# 261                   53      Australia and New Zealand  2010
#
#                                                 Series    Value Footnotes  \
# 0    Safely managed drinking water sources, urban (...  86.1804       NaN
# ...

# %%
df2.columns
# Out:
# Index(['Region/Country/Area', 'Unnamed: 1', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df [['Region/Country/Area', 'Unnamed: 1', 'Year', 'Series', 'Value']]
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2000
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2016
# ...                   ...                            ...   ...
# 1464                  716                       Zimbabwe  2005
# 1465                  716                       Zimbabwe  2010
# 1466                  716                       Zimbabwe  2015
# 1467                  716                       Zimbabwe  2016
# 1468                  716                       Zimbabwe  2017
#
#                                             Series    Value
# 0     Percentage of individuals using the internet   6.5316
# 1     Percentage of individuals using the internet  15.6777
# ...

# %% [markdown]
# les 258 lignes portent sur des zones consolidées
# A partir de la 259, par pays // Australia

# %% [markdown]
# Qu'est ce que je veux faire ?
# Comparer dans le temps,  l'accès à l'eau potable et à internet, dans chaque aire géographique.
# Année commune 2005, 2010, 2017
