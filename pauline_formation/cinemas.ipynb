# %%
import pandas as pd

# %%
df = pd.read_csv('cinema.csv', sep=';', skiprows=11, index_col=['Année', 'Régions linguistiques'])

# %%
df.head()
# Out:
#                             Total Entrées de cinéma   \
# Année Régions linguistiques
# 1995  Total                               14 796 645
#       Suisse alémanique                    9 576 244
#       Suisse romande                       4 784 593
#       Suisse italienne                       435 808
# 1996  Total                               15 148 879
#
#                             Suisse en valeurs absolues Suisse en %  \
# Année Régions linguistiques
# 1995  Total                                    218 700         1,5
#       Suisse alémanique                        178 225         1,9
#       Suisse romande                            40 279         0,8
#       Suisse italienne                             196         0,0
# 1996  Total                                    247 043         1,6
#
#                             USA en valeurs absolues USA en %  \
# Année Régions linguistiques
# 1995  Total                              10 828 121     73,2
# ...

# %%
Suisse_romande = df['Régions linguistiques'] == 'Suisse romande'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Régions linguistiques'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-6b73d8d3f37f> in <module>
# ...
